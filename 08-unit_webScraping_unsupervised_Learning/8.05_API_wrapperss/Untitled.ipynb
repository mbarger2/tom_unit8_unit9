# %%
import sys
import spotipy

# %%
# sys.argv

# %%
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id="30da7dcb7eeb4f038924583a5dc6dfb3",
                                                           client_secret="d4d0d4cc03c3457bb24ec6dd80b17441"))

# %%
playlists = sp.user_playlists('spotify')

# %%
playlists = sp.user_playlists('gl1vslavu5wmabs68y6h2zhrz')

# %%
len(playlists['items'])
# Out:
# 20

# %%
playlists
# Out:
# {'href': 'https://api.spotify.com/v1/users/gl1vslavu5wmabs68y6h2zhrz/playlists?offset=0&limit=50',
#  'items': [{'collaborative': False,
#    'description': '',
#    'external_urls': {'spotify': 'https://open.spotify.com/playlist/5FcATUtr2eXdahFwDYHV6O'},
#    'href': 'https://api.spotify.com/v1/playlists/5FcATUtr2eXdahFwDYHV6O',
#    'id': '5FcATUtr2eXdahFwDYHV6O',
#    'images': [{'height': 640,
#      'url': 'https://mosaic.scdn.co/640/ab67616d0000b2737b9639babbe96e25071ec1d4ab67616d0000b273d06bd6d3b1f258ba2bca597aab67616d0000b273df55e326ed144ab4f5cecf95ab67616d0000b273ed801e58a9ababdea6ac7ce4',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://mosaic.scdn.co/300/ab67616d0000b2737b9639babbe96e25071ec1d4ab67616d0000b273d06bd6d3b1f258ba2bca597aab67616d0000b273df55e326ed144ab4f5cecf95ab67616d0000b273ed801e58a9ababdea6ac7ce4',
#      'width': 300},
#     {'height': 60,
# ...

# %%
playlists.keys()
# Out:
# dict_keys(['href', 'items', 'limit', 'next', 'offset', 'previous', 'total'])

# %%
len(playlists['items'])
# Out:
# 50

# %%
playlists['next']
# Out:
# 'https://api.spotify.com/v1/users/spotify/playlists?offset=50&limit=50'

# %%
len(playlists['items'])
# Out:
# 50

# %%
playlists['items'][15]
# Out:
# {'collaborative': False,
#  'description': 'The biggest songs of the 1970s.\n',
#  'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DWTJ7xPn4vNaz'},
#  'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTJ7xPn4vNaz',
#  'id': '37i9dQZF1DWTJ7xPn4vNaz',
#  'images': [{'height': None,
#    'url': 'https://i.scdn.co/image/ab67706f000000039fa1360866a192b74548cd3c',
#    'width': None}],
#  'name': 'All Out 70s',
#  'owner': {'display_name': 'Spotify',
#   'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#   'href': 'https://api.spotify.com/v1/users/spotify',
#   'id': 'spotify',
#   'type': 'user',
#   'uri': 'spotify:user:spotify'},
#  'primary_color': None,
#  'public': True,
#  'snapshot_id': 'MTY0MTk2NzIwNSwwMDAwMDBiYjAwMDAwMTdlNGNkZjNkZGEwMDAwMDE3ZDM4NGUyMjlk',
#  'tracks': {'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DWTJ7xPn4vNaz/tracks',
#   'total': 150},
#  'type': 'playlist',
# ...

# %%
sp.featured_playlists()
# Out:
# {'message': "Editor's picks",
#  'playlists': {'href': 'https://api.spotify.com/v1/browse/featured-playlists?timestamp=2022-01-13T22%3A18%3A02&offset=0&limit=20',
#   'items': [{'collaborative': False,
#     'description': "Calm Down with this chilled out playlist. For when it's time to just sit and bask in the afterglow.",
#     'external_urls': {'spotify': 'https://open.spotify.com/playlist/37i9dQZF1DX5bjCEbRU4SJ'},
#     'href': 'https://api.spotify.com/v1/playlists/37i9dQZF1DX5bjCEbRU4SJ',
#     'id': '37i9dQZF1DX5bjCEbRU4SJ',
#     'images': [{'height': None,
#       'url': 'https://i.scdn.co/image/ab67706f00000003278197087524cc094f86e82b',
#       'width': None}],
#     'name': 'Calm Down',
#     'owner': {'display_name': 'Spotify',
#      'external_urls': {'spotify': 'https://open.spotify.com/user/spotify'},
#      'href': 'https://api.spotify.com/v1/users/spotify',
#      'id': 'spotify',
#      'type': 'user',
#      'uri': 'spotify:user:spotify'},
# ...

# %%
import pandas as pd
data = pd.read_csv('songs.csv')

# %%
data.head()
# Out:
#    Unnamed: 0                 song_id               artist_id artist_name  \
# 0           0  4rcSvYi807urIIqfeX3tBo  2FXC3k01G6Gw61bmprjgqS      Hozier
# 1           1  2QsquiKBcjvDUlO6QyvMEs  2FXC3k01G6Gw61bmprjgqS      Hozier
# 2           2  70LrxJ5u19umvrXbC19g20  2FXC3k01G6Gw61bmprjgqS      Hozier
# 3           3  0aOluBqXYd0rFSCsgDyAWX  2FXC3k01G6Gw61bmprjgqS      Hozier
# 4           4  1CS7Sd1u5tWkstBhpssyjP  2FXC3k01G6Gw61bmprjgqS      Hozier
#
#                                 song_name  \
# 0  Nina Cried Power (feat. Mavis Staples)
# 1                        Nina Cried Power
# 2                       Take Me To Church
# 3                       Take Me to Church
# 4                       Take Me to Church
#
#                                       audio_features
# 0  {'danceability': 0.365, 'energy': 0.875, 'key'...
# 1  {'danceability': 0.365, 'energy': 0.875, 'key'...
# 2  {'danceability': 0.566, 'energy': 0.664, 'key'...
# ...

# %%
data = data.dropna()

# %%
data['audio_features'] = list(map(lambda x: x.replace("'", "\""), data['audio_features']))
# Out:
# <ipython-input-58-b9e46d02fb7b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['audio_features'] = list(map(lambda x: x.replace("'", "\""), data['audio_features']))

# %%
data['audio_features'] = list(map(lambda x: json.loads(x), data['audio_features']))
# Out:
# <ipython-input-60-01807d2a2b6a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['audio_features'] = list(map(lambda x: json.loads(x), data['audio_features']))

# %%
data['audio_features'][0]
# Out:
# {'danceability': 0.365,
#  'energy': 0.875,
#  'key': 1,
#  'loudness': -3.228,
#  'mode': 1,
#  'speechiness': 0.131,
#  'acousticness': 0.00893,
#  'instrumentalness': 0,
#  'liveness': 0.0786,
#  'valence': 0.655,
#  'tempo': 98.708,
#  'type': 'audio_features',
#  'id': '4rcSvYi807urIIqfeX3tBo',
#  'uri': 'spotify:track:4rcSvYi807urIIqfeX3tBo',
#  'track_href': 'https://api.spotify.com/v1/tracks/4rcSvYi807urIIqfeX3tBo',
#  'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4rcSvYi807urIIqfeX3tBo',
#  'duration_ms': 225307,
#  'time_signature': 4}

# %%
pd.json_normalize(data['audio_features'])
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.365   0.875    1    -3.228     1       0.1310       0.00893
# 1           0.365   0.875    1    -3.228     1       0.1310       0.00893
# 2           0.566   0.664    4    -5.303     0       0.0464       0.63400
# 3           0.575   0.664    4    -5.303     0       0.0481       0.63700
# 4           0.566   0.664    4    -5.303     0       0.0464       0.63400
# ..            ...     ...  ...       ...   ...          ...           ...
# 630         0.848   0.675   11    -3.611     0       0.0445       0.00273
# 631         0.845   0.818   11    -3.736     0       0.2230       0.05350
# 632         0.678   0.870    6    -3.132     1       0.1820       0.05560
# 633         0.683   0.906    6    -4.540     0       0.1300       0.16200
# 634         0.737   0.863    6    -2.533     0       0.0605       0.06710
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
x = [1,2,31,1,1,1,2,3]

# %%
list(set(x))
# Out:
# [1, 2, 3, 31]
