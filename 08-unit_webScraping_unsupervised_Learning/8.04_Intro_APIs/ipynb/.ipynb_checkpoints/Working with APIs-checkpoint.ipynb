# %%
import requests
import pandas as pd

# %%
response = requests.get('https://api.github.com/events')
data = pd.DataFrame(response.json())
data.head()
# Out:
#             id                    type  \
# 0  19665372613             CreateEvent
# 1  19665372592  PullRequestReviewEvent
# 2  19665372585               PushEvent
# 3  19665372604       IssueCommentEvent
# 4  19665372591               PushEvent
#
#                                                actor  \
# 0  {'id': 37245253, 'login': 'fazenecture', 'disp...
# 1  {'id': 3010904, 'login': 'postamar', 'display_...
# 2  {'id': 97123285, 'login': 'brokjad', 'display_...
# 3  {'id': 13698158, 'login': 'tqureshi-uog', 'dis...
# 4  {'id': 56795920, 'login': 'kitkovsky', 'displa...
#
#                                                 repo  \
# 0  {'id': 446592245, 'name': 'fazenecture/shop-we...
# 1  {'id': 16563587, 'name': 'cockroachdb/cockroac...
# 2  {'id': 444526767, 'name': 'brokjad/got_config'...
# 3  {'id': 316041681, 'name': 'ccswbs/gus', 'url':...
# 4  {'id': 446591460, 'name': 'kitkovsky/.dotfiles...
#
#                                              payload  public  \
# 0  {'ref': 'main', 'ref_type': 'branch', 'master_...    True
# 1  {'action': 'created', 'review': {'id': 8483921...    True
# 2  {'push_id': 8800755544, 'size': 1, 'distinct_s...    True
# 3  {'action': 'created', 'issue': {'url': 'https:...    True
# 4  {'push_id': 8800755547, 'size': 1, 'distinct_s...    True
#
#              created_at                                                org
# 0  2022-01-10T21:48:38Z                                                NaN
# 1  2022-01-10T21:48:38Z  {'id': 6748139, 'login': 'cockroachdb', 'grava...
# 2  2022-01-10T21:48:38Z                                                NaN
# 3  2022-01-10T21:48:38Z  {'id': 15328052, 'login': 'ccswbs', 'gravatar_...
# 4  2022-01-10T21:48:38Z                                                NaN

# %%
response.json()
# Out:
# [{'id': '19665372613',
#   'type': 'CreateEvent',
#   'actor': {'id': 37245253,
#    'login': 'fazenecture',
#    'display_login': 'fazenecture',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fazenecture',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37245253?'},
#   'repo': {'id': 446592245,
#    'name': 'fazenecture/shop-website-nodejs',
#    'url': 'https://api.github.com/repos/fazenecture/shop-website-nodejs'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z'},
#  {'id': '19665372592',
#   'type': 'PullRequestReviewEvent',
#   'actor': {'id': 3010904,
#    'login': 'postamar',
#    'display_login': 'postamar',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/postamar',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3010904?'},
#   'repo': {'id': 16563587,
#    'name': 'cockroachdb/cockroach',
#    'url': 'https://api.github.com/repos/cockroachdb/cockroach'},
#   'payload': {'action': 'created',
#    'review': {'id': 848392154,
#     'node_id': 'PRR_kwDOAPy9g84ykW_a',
#     'user': {'login': 'postamar',
#      'id': 3010904,
#      'node_id': 'MDQ6VXNlcjMwMTA5MDQ=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/3010904?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/postamar',
#      'html_url': 'https://github.com/postamar',
#      'followers_url': 'https://api.github.com/users/postamar/followers',
#      'following_url': 'https://api.github.com/users/postamar/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/postamar/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/postamar/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/postamar/subscriptions',
#      'organizations_url': 'https://api.github.com/users/postamar/orgs',
#      'repos_url': 'https://api.github.com/users/postamar/repos',
#      'events_url': 'https://api.github.com/users/postamar/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/postamar/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "I took a look at this. Please bear in mind that my review is very superficial. I didn't find anything obviously wrong in this PR. You should probably have someone more knowledgeable take a look. Please bear in mind that it's OK to annoy people for reviews :+1: \n\n> Reviewed 1 of 8 files at r1, 1 of 4 files at r2, 1 of 2 files at r3.\n> *[Reviewable](https://reviewable.io/reviews/cockroachdb/cockroach/74179#-:-Mt4xQHM8zZO419ZZpT-:bxg2iqu)* status: :shipit: complete! 0 of 0 LGTMs obtained (waiting on @ajwerner and @chengxiong-ruan)\n\n___\n*[-- commits, line 2 at r3](https://reviewable.io/reviews/cockroachdb/cockroach/74179#-Mt4t4qw0Cr-COrn5WLM):*\ns/quivalent/equivalent/\n___\n*[-- commits, line 16 at r3](https://reviewable.io/reviews/cockroachdb/cockroach/74179#-Mt4tall6TGFNtCBtY7g):*\nCan you please reword this sentence?\n___\n*[pkg/sql/create_table.go, line 1645 at r1](https://reviewable.io/reviews/cockroachdb/cockroach/74179#-MrVO6M33TO4gjp2ZYhI:-Mt4vyNb3lLHa8KgmMDm:b-5w7mug) ([raw file](https://github.com/cockroachdb/cockroach/blob/fc13e138efc4b44c4b5b35b1096dc129a23018a2/pkg/sql/create_table.go#L1645)):*\n<details><summary><i>Previously, chengxiong-ruan (Chengxiong Ruan) wrote…</i></summary><blockquote>\n\nI kept questioning myself why we want to make a user defined constraint hidden.\n\nI think my answer is that we may want to have a consistent `SHOW CREATE` experience for tables with hash sharded index, and it should be super rare that a super smart user defined a equivalent constraint for a shard column if we don't show the constraint at all >_> But if there would be a super smart user, showing the constraint would give them a chance to drop the constraint, do we want that? Dropping the constraint in this case could be fine since we trust the shard column so much that we skip validation during backfill already. The only thing is how optimizer gonna feel, I think it's also fine since it's user's choice.\n\nHowever step back a bit I also questioned myself, why do we need all these equivalent constraint check at all. Why can't we just try to create the constraint anyway without checking? In this case, if a smart user defined an exactly same constraint, it would fail due to duplicated constraint. I think it's also an ok experience for user and this whole block of code would be gone.\n</blockquote></details>\n\nI may be wrong here, and I don't understand any of this too deeply, however I believe that anything that has `crdb_internal` in its name is assumed to not have been created by a user. This isn't enforced anywhere, but it is a convention.\n\nI believe the goal here is that we want the output of a `SHOW CREATE TABLE` statement for a hash-sharded table to round-trip correctly. In other words, that executing the resulting `CREATE TABLE` statement would produce the same table.\n\nI may be completely wrong here.\n___\n*[pkg/sql/create_table.go, line 1623 at r3](https://reviewable.io/reviews/cockroachdb/cockroach/74179#-Mt4v2Pk97RyVcJo-_kP:-Mt4v2Pk97RyVcJo-_kQ:b-5k5tor) ([raw file](https://github.com/cockroachdb/cockroach/blob/7ac4cb86a5714e3f11b31fbf668aa01945f4a6bb/pkg/sql/create_table.go#L1623)):*\n> ```Go\n> \t\t}\n> \n> \t\t// if there is an equivalent check constraint from the CREATE TABLE (should be rare since we hide the constraint of shard column)\n> ```\n\nstyle: comments should wrap around at the 80th character column\n\n\n<!-- Sent from Reviewable.io -->\n",
#     'commit_id': '7ac4cb86a5714e3f11b31fbf668aa01945f4a6bb',
#     'submitted_at': '2022-01-10T21:48:38Z',
#     'state': 'commented',
#     'html_url': 'https://github.com/cockroachdb/cockroach/pull/74179#pullrequestreview-848392154',
#     'pull_request_url': 'https://api.github.com/repos/cockroachdb/cockroach/pulls/74179',
#     'author_association': 'COLLABORATOR',
#     '_links': {'html': {'href': 'https://github.com/cockroachdb/cockroach/pull/74179#pullrequestreview-848392154'},
#      'pull_request': {'href': 'https://api.github.com/repos/cockroachdb/cockroach/pulls/74179'}}},
#    'pull_request': {'url': 'https://api.github.com/repos/cockroachdb/cockroach/pulls/74179',
#     'id': 807943109,
#     'node_id': 'PR_kwDOAPy9g84wKDvF',
#     'html_url': 'https://github.com/cockroachdb/cockroach/pull/74179',
#     'diff_url': 'https://github.com/cockroachdb/cockroach/pull/74179.diff',
#     'patch_url': 'https://github.com/cockroachdb/cockroach/pull/74179.patch',
#     'issue_url': 'https://api.github.com/repos/cockroachdb/cockroach/issues/74179',
#     'number': 74179,
#     'state': 'open',
#     'locked': False,
#     'title': 'sql: check quivalent constraint when creating hash index',
#     'user': {'login': 'chengxiong-ruan',
#      'id': 6616651,
#      'node_id': 'MDQ6VXNlcjY2MTY2NTE=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/6616651?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/chengxiong-ruan',
#      'html_url': 'https://github.com/chengxiong-ruan',
#      'followers_url': 'https://api.github.com/users/chengxiong-ruan/followers',
#      'following_url': 'https://api.github.com/users/chengxiong-ruan/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/chengxiong-ruan/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/chengxiong-ruan/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/chengxiong-ruan/subscriptions',
#      'organizations_url': 'https://api.github.com/users/chengxiong-ruan/orgs',
#      'repos_url': 'https://api.github.com/users/chengxiong-ruan/repos',
#      'events_url': 'https://api.github.com/users/chengxiong-ruan/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/chengxiong-ruan/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "Fixes #68031\r\n\r\nPreviously we only try to create constraint for shard column if\r\nit's newly created. We check duplicate constraint for shard\r\ncolumn when `Alter Primary Key` and `Create Index`, however the\r\ncheck is simply a name check. This pr adds logic to check\r\nequivalent constraint by checking if the formatted expression\r\nstring is the same.\r\n\r\nRelease note (sql change): Shard column constraint is not visible\r\nany more. Creating a hash index would make sure the constraint is\r\ncreated not matter there's a existing or user defined equivalent\r\ncolumn.",
#     'created_at': '2021-12-21T23:03:10Z',
#     'updated_at': '2022-01-10T21:48:38Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'f0d63ce29ec09546e9bf336ce4b52c39d6f2dfa6',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [{'login': 'ajwerner',
#       'id': 1839234,
#       'node_id': 'MDQ6VXNlcjE4MzkyMzQ=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/1839234?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/ajwerner',
#       'html_url': 'https://github.com/ajwerner',
#       'followers_url': 'https://api.github.com/users/ajwerner/followers',
#       'following_url': 'https://api.github.com/users/ajwerner/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/ajwerner/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/ajwerner/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/ajwerner/subscriptions',
#       'organizations_url': 'https://api.github.com/users/ajwerner/orgs',
#       'repos_url': 'https://api.github.com/users/ajwerner/repos',
#       'events_url': 'https://api.github.com/users/ajwerner/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/ajwerner/received_events',
#       'type': 'User',
#       'site_admin': False}],
#     'requested_teams': [],
#     'labels': [],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/cockroachdb/cockroach/pulls/74179/commits',
#     'review_comments_url': 'https://api.github.com/repos/cockroachdb/cockroach/pulls/74179/comments',
#     'review_comment_url': 'https://api.github.com/repos/cockroachdb/cockroach/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/cockroachdb/cockroach/issues/74179/comments',
#     'statuses_url': 'https://api.github.com/repos/cockroachdb/cockroach/statuses/7ac4cb86a5714e3f11b31fbf668aa01945f4a6bb',
#     'head': {'label': 'chengxiong-ruan:check-equivalent-shard-col-constraint',
#      'ref': 'check-equivalent-shard-col-constraint',
#      'sha': '7ac4cb86a5714e3f11b31fbf668aa01945f4a6bb',
#      'user': {'login': 'chengxiong-ruan',
#       'id': 6616651,
#       'node_id': 'MDQ6VXNlcjY2MTY2NTE=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/6616651?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/chengxiong-ruan',
#       'html_url': 'https://github.com/chengxiong-ruan',
#       'followers_url': 'https://api.github.com/users/chengxiong-ruan/followers',
#       'following_url': 'https://api.github.com/users/chengxiong-ruan/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/chengxiong-ruan/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/chengxiong-ruan/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/chengxiong-ruan/subscriptions',
#       'organizations_url': 'https://api.github.com/users/chengxiong-ruan/orgs',
#       'repos_url': 'https://api.github.com/users/chengxiong-ruan/repos',
#       'events_url': 'https://api.github.com/users/chengxiong-ruan/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/chengxiong-ruan/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 423314318,
#       'node_id': 'R_kgDOGTtDjg',
#       'name': 'cockroach',
#       'full_name': 'chengxiong-ruan/cockroach',
#       'private': False,
#       'owner': {'login': 'chengxiong-ruan',
#        'id': 6616651,
#        'node_id': 'MDQ6VXNlcjY2MTY2NTE=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/6616651?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/chengxiong-ruan',
#        'html_url': 'https://github.com/chengxiong-ruan',
#        'followers_url': 'https://api.github.com/users/chengxiong-ruan/followers',
#        'following_url': 'https://api.github.com/users/chengxiong-ruan/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/chengxiong-ruan/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/chengxiong-ruan/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/chengxiong-ruan/subscriptions',
#        'organizations_url': 'https://api.github.com/users/chengxiong-ruan/orgs',
#        'repos_url': 'https://api.github.com/users/chengxiong-ruan/repos',
#        'events_url': 'https://api.github.com/users/chengxiong-ruan/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/chengxiong-ruan/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/chengxiong-ruan/cockroach',
#       'description': 'CockroachDB - the open source, cloud-native distributed SQL database.',
#       'fork': True,
#       'url': 'https://api.github.com/repos/chengxiong-ruan/cockroach',
#       'forks_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/forks',
#       'keys_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/teams',
#       'hooks_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/hooks',
#       'issue_events_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/events',
#       'assignees_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/tags',
#       'blobs_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/languages',
#       'stargazers_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/stargazers',
#       'contributors_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/contributors',
#       'subscribers_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/subscribers',
#       'subscription_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/subscription',
#       'commits_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/merges',
#       'archive_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/downloads',
#       'issues_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/chengxiong-ruan/cockroach/deployments',
#       'created_at': '2021-11-01T02:32:11Z',
#       'updated_at': '2022-01-10T15:25:36Z',
#       'pushed_at': '2022-01-10T18:56:42Z',
#       'git_url': 'git://github.com/chengxiong-ruan/cockroach.git',
#       'ssh_url': 'git@github.com:chengxiong-ruan/cockroach.git',
#       'clone_url': 'https://github.com/chengxiong-ruan/cockroach.git',
#       'svn_url': 'https://github.com/chengxiong-ruan/cockroach',
#       'homepage': 'https://www.cockroachlabs.com',
#       'size': 1102778,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'Go',
#       'has_issues': False,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 0,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': [],
#       'visibility': 'public',
#       'forks': 0,
#       'open_issues': 0,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     'base': {'label': 'cockroachdb:master',
#      'ref': 'master',
#      'sha': '691f4a40183daee9389a6f79701bd74664d0ff88',
#      'user': {'login': 'cockroachdb',
#       'id': 6748139,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY3NDgxMzk=',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/6748139?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/cockroachdb',
#       'html_url': 'https://github.com/cockroachdb',
#       'followers_url': 'https://api.github.com/users/cockroachdb/followers',
#       'following_url': 'https://api.github.com/users/cockroachdb/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/cockroachdb/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/cockroachdb/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/cockroachdb/subscriptions',
#       'organizations_url': 'https://api.github.com/users/cockroachdb/orgs',
#       'repos_url': 'https://api.github.com/users/cockroachdb/repos',
#       'events_url': 'https://api.github.com/users/cockroachdb/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/cockroachdb/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 16563587,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxNjU2MzU4Nw==',
#       'name': 'cockroach',
#       'full_name': 'cockroachdb/cockroach',
#       'private': False,
#       'owner': {'login': 'cockroachdb',
#        'id': 6748139,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjY3NDgxMzk=',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/6748139?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/cockroachdb',
#        'html_url': 'https://github.com/cockroachdb',
#        'followers_url': 'https://api.github.com/users/cockroachdb/followers',
#        'following_url': 'https://api.github.com/users/cockroachdb/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/cockroachdb/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/cockroachdb/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/cockroachdb/subscriptions',
#        'organizations_url': 'https://api.github.com/users/cockroachdb/orgs',
#        'repos_url': 'https://api.github.com/users/cockroachdb/repos',
#        'events_url': 'https://api.github.com/users/cockroachdb/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/cockroachdb/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/cockroachdb/cockroach',
#       'description': 'CockroachDB - the open source, cloud-native distributed SQL database.',
#       'fork': False,
#       'url': 'https://api.github.com/repos/cockroachdb/cockroach',
#       'forks_url': 'https://api.github.com/repos/cockroachdb/cockroach/forks',
#       'keys_url': 'https://api.github.com/repos/cockroachdb/cockroach/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/cockroachdb/cockroach/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/cockroachdb/cockroach/teams',
#       'hooks_url': 'https://api.github.com/repos/cockroachdb/cockroach/hooks',
#       'issue_events_url': 'https://api.github.com/repos/cockroachdb/cockroach/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/cockroachdb/cockroach/events',
#       'assignees_url': 'https://api.github.com/repos/cockroachdb/cockroach/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/cockroachdb/cockroach/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/cockroachdb/cockroach/tags',
#       'blobs_url': 'https://api.github.com/repos/cockroachdb/cockroach/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/cockroachdb/cockroach/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/cockroachdb/cockroach/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/cockroachdb/cockroach/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/cockroachdb/cockroach/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/cockroachdb/cockroach/languages',
#       'stargazers_url': 'https://api.github.com/repos/cockroachdb/cockroach/stargazers',
#       'contributors_url': 'https://api.github.com/repos/cockroachdb/cockroach/contributors',
#       'subscribers_url': 'https://api.github.com/repos/cockroachdb/cockroach/subscribers',
#       'subscription_url': 'https://api.github.com/repos/cockroachdb/cockroach/subscription',
#       'commits_url': 'https://api.github.com/repos/cockroachdb/cockroach/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/cockroachdb/cockroach/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/cockroachdb/cockroach/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/cockroachdb/cockroach/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/cockroachdb/cockroach/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/cockroachdb/cockroach/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/cockroachdb/cockroach/merges',
#       'archive_url': 'https://api.github.com/repos/cockroachdb/cockroach/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/cockroachdb/cockroach/downloads',
#       'issues_url': 'https://api.github.com/repos/cockroachdb/cockroach/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/cockroachdb/cockroach/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/cockroachdb/cockroach/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/cockroachdb/cockroach/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/cockroachdb/cockroach/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/cockroachdb/cockroach/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/cockroachdb/cockroach/deployments',
#       'created_at': '2014-02-06T00:18:47Z',
#       'updated_at': '2022-01-10T20:10:24Z',
#       'pushed_at': '2022-01-10T21:44:38Z',
#       'git_url': 'git://github.com/cockroachdb/cockroach.git',
#       'ssh_url': 'git@github.com:cockroachdb/cockroach.git',
#       'clone_url': 'https://github.com/cockroachdb/cockroach.git',
#       'svn_url': 'https://github.com/cockroachdb/cockroach',
#       'homepage': 'https://www.cockroachlabs.com',
#       'size': 1844004,
#       'stargazers_count': 23079,
#       'watchers_count': 23079,
#       'language': 'Go',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 2996,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 4527,
#       'license': {'key': 'other',
#        'name': 'Other',
#        'spdx_id': 'NOASSERTION',
#        'url': None,
#        'node_id': 'MDc6TGljZW5zZTA='},
#       'allow_forking': True,
#       'is_template': False,
#       'topics': ['cockroachdb',
#        'database',
#        'distributed-database',
#        'go',
#        'hacktoberfest',
#        'sql'],
#       'visibility': 'public',
#       'forks': 2996,
#       'open_issues': 4527,
#       'watchers': 23079,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/cockroachdb/cockroach/pulls/74179'},
#      'html': {'href': 'https://github.com/cockroachdb/cockroach/pull/74179'},
#      'issue': {'href': 'https://api.github.com/repos/cockroachdb/cockroach/issues/74179'},
#      'comments': {'href': 'https://api.github.com/repos/cockroachdb/cockroach/issues/74179/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/cockroachdb/cockroach/pulls/74179/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/cockroachdb/cockroach/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/cockroachdb/cockroach/pulls/74179/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/cockroachdb/cockroach/statuses/7ac4cb86a5714e3f11b31fbf668aa01945f4a6bb'}},
#     'author_association': 'COLLABORATOR',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z',
#   'org': {'id': 6748139,
#    'login': 'cockroachdb',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/cockroachdb',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6748139?'}},
#  {'id': '19665372585',
#   'type': 'PushEvent',
#   'actor': {'id': 97123285,
#    'login': 'brokjad',
#    'display_login': 'brokjad',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/brokjad',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97123285?'},
#   'repo': {'id': 444526767,
#    'name': 'brokjad/got_config',
#    'url': 'https://api.github.com/repos/brokjad/got_config'},
#   'payload': {'push_id': 8800755544,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': '38a6d06928d2ba4df31785d07bd774f79edcd083',
#    'before': 'de6719796b4fde2d95df6d392f9db8f85d359e70',
#    'commits': [{'sha': '38a6d06928d2ba4df31785d07bd774f79edcd083',
#      'author': {'email': '97123285+brokjad@users.noreply.github.com',
#       'name': 'brokjad'},
#      'message': 'update_log',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/brokjad/got_config/commits/38a6d06928d2ba4df31785d07bd774f79edcd083'}]},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z'},
#  {'id': '19665372604',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 13698158,
#    'login': 'tqureshi-uog',
#    'display_login': 'tqureshi-uog',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/tqureshi-uog',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13698158?'},
#   'repo': {'id': 316041681,
#    'name': 'ccswbs/gus',
#    'url': 'https://api.github.com/repos/ccswbs/gus'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/ccswbs/gus/issues/53',
#     'repository_url': 'https://api.github.com/repos/ccswbs/gus',
#     'labels_url': 'https://api.github.com/repos/ccswbs/gus/issues/53/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ccswbs/gus/issues/53/comments',
#     'events_url': 'https://api.github.com/repos/ccswbs/gus/issues/53/events',
#     'html_url': 'https://github.com/ccswbs/gus/pull/53',
#     'id': 1098214470,
#     'node_id': 'PR_kwDOEtZp0c4wwAU0',
#     'number': 53,
#     'title': 'Wp events',
#     'user': {'login': 'abanuog',
#      'id': 15928442,
#      'node_id': 'MDQ6VXNlcjE1OTI4NDQy',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/15928442?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/abanuog',
#      'html_url': 'https://github.com/abanuog',
#      'followers_url': 'https://api.github.com/users/abanuog/followers',
#      'following_url': 'https://api.github.com/users/abanuog/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/abanuog/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/abanuog/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/abanuog/subscriptions',
#      'organizations_url': 'https://api.github.com/users/abanuog/orgs',
#      'repos_url': 'https://api.github.com/users/abanuog/repos',
#      'events_url': 'https://api.github.com/users/abanuog/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/abanuog/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 4,
#     'created_at': '2022-01-10T18:07:05Z',
#     'updated_at': '2022-01-10T21:48:38Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/ccswbs/gus/pulls/53',
#      'html_url': 'https://github.com/ccswbs/gus/pull/53',
#      'diff_url': 'https://github.com/ccswbs/gus/pull/53.diff',
#      'patch_url': 'https://github.com/ccswbs/gus/pull/53.patch',
#      'merged_at': None},
#     'body': 'Show events data from a WordPress site, on basic pages (if the option is set to true)\r\n\r\nFRONTEND (Gatsby): \r\n- gatsby-config.js - added styled components and graphql source plugins\r\n- gatsby-node.js - updated schema for show events field\r\n- src/components/events.js - new component\r\n- src/templates/basic-page.js - show events data \r\n\r\n\r\nBACKEND (Drupal): multidev\r\n- added checkbox field to basic page to show events data (https://wp-events-chug.pantheonsite.io/). Field will be added to other multidevs after PR review\r\n\r\nTESTING: \r\nThe backend is at https://wp-events-chug.pantheonsite.io/ so you will need to update the ENV variable when running gatsby develop. The page "TEST - New International Students" will show the events at the top of the page. Other pages don\'t have the field set, so shouldn\'t show the events.',
#     'reactions': {'url': 'https://api.github.com/repos/ccswbs/gus/issues/53/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/ccswbs/gus/issues/53/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/ccswbs/gus/issues/comments/1009376326',
#     'html_url': 'https://github.com/ccswbs/gus/pull/53#issuecomment-1009376326',
#     'issue_url': 'https://api.github.com/repos/ccswbs/gus/issues/53',
#     'id': 1009376326,
#     'node_id': 'IC_kwDOEtZp0c48KdxG',
#     'user': {'login': 'tqureshi-uog',
#      'id': 13698158,
#      'node_id': 'MDQ6VXNlcjEzNjk4MTU4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/13698158?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/tqureshi-uog',
#      'html_url': 'https://github.com/tqureshi-uog',
#      'followers_url': 'https://api.github.com/users/tqureshi-uog/followers',
#      'following_url': 'https://api.github.com/users/tqureshi-uog/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/tqureshi-uog/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/tqureshi-uog/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/tqureshi-uog/subscriptions',
#      'organizations_url': 'https://api.github.com/users/tqureshi-uog/orgs',
#      'repos_url': 'https://api.github.com/users/tqureshi-uog/repos',
#      'events_url': 'https://api.github.com/users/tqureshi-uog/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/tqureshi-uog/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2022-01-10T21:48:38Z',
#     'updated_at': '2022-01-10T21:48:38Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': '@abanuog Please create a preview site for this feature branch on Gatsby Cloud as per https://dev.azure.com/uoguelph/CCS/_wiki/wikis/WCM%20Content%20Hub%20Wiki/1395/Previewing-changes-on-Gatsby-Cloud?anchor=using-gatsby-cloud-to-preview-a-multidev-and-feature-branch \r\n\r\nSee https://www.gatsbyjs.com/dashboard/2e86c058-a370-4898-ae51-9698cd178e8d/sites/e1480ab1-9d0f-4dcb-9fda-75347c74c1c9 and https://www.gatsbyjs.com/dashboard/2e86c058-a370-4898-ae51-9698cd178e8d/sites/4d03c6f6-9271-4faf-8419-e36460e489d7/deploys for examples',
#     'reactions': {'url': 'https://api.github.com/repos/ccswbs/gus/issues/comments/1009376326/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z',
#   'org': {'id': 15328052,
#    'login': 'ccswbs',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ccswbs',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15328052?'}},
#  {'id': '19665372591',
#   'type': 'PushEvent',
#   'actor': {'id': 56795920,
#    'login': 'kitkovsky',
#    'display_login': 'kitkovsky',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kitkovsky',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/56795920?'},
#   'repo': {'id': 446591460,
#    'name': 'kitkovsky/.dotfiles',
#    'url': 'https://api.github.com/repos/kitkovsky/.dotfiles'},
#   'payload': {'push_id': 8800755547,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'be1097ce74c8fcc802493b7f3b35da219e5f7d81',
#    'before': '96f0c5398356db307e75e358286699e678ba0662',
#    'commits': [{'sha': 'be1097ce74c8fcc802493b7f3b35da219e5f7d81',
#      'author': {'email': 'okitkowski114@gmail.com',
#       'name': 'Oliwer Kitkowski'},
#      'message': 'fix links?',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/kitkovsky/.dotfiles/commits/be1097ce74c8fcc802493b7f3b35da219e5f7d81'}]},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z'},
#  {'id': '19665372587',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 86929735,
#    'name': 'Lombiq/Orchard',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard'},
#   'payload': {'push_id': 8800755535,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/issue/5791/homealias',
#    'head': 'd0e7c09ba504b16ac793d3018a3bd55d389a32c8',
#    'before': 'd0e7c09ba504b16ac793d3018a3bd55d389a32c8',
#    'commits': []},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '19665372565',
#   'type': 'PushEvent',
#   'actor': {'id': 65306522,
#    'login': 'Olga1506',
#    'display_login': 'Olga1506',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Olga1506',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/65306522?'},
#   'repo': {'id': 439409185,
#    'name': 'Olga1506/FREE-PSD',
#    'url': 'https://api.github.com/repos/Olga1506/FREE-PSD'},
#   'payload': {'push_id': 8800755516,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'e2d6fd5d9ee914cbb1be4582bd6e76a3febf8592',
#    'before': '3d35ef199dfb061d6da102bbda4b9e3296d2af7c',
#    'commits': [{'sha': 'e2d6fd5d9ee914cbb1be4582bd6e76a3febf8592',
#      'author': {'email': 'bolga1626@gmail.com', 'name': 'Olga1506'},
#      'message': 'news',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Olga1506/FREE-PSD/commits/e2d6fd5d9ee914cbb1be4582bd6e76a3febf8592'}]},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z'},
#  {'id': '19665372586',
#   'type': 'PushEvent',
#   'actor': {'id': 48661356,
#    'login': 'BennyBot',
#    'display_login': 'BennyBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/BennyBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/48661356?'},
#   'repo': {'id': 304201023,
#    'name': 'purduesigbots/pros-vsc',
#    'url': 'https://api.github.com/repos/purduesigbots/pros-vsc'},
#   'payload': {'push_id': 8800755526,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/feature/one-click',
#    'head': '0a9b1421d420955df696722fd5e1f669da43a1b1',
#    'before': '601831792a58f5fd3433a92b6d38ed7e1d530970',
#    'commits': [{'sha': '0a9b1421d420955df696722fd5e1f669da43a1b1',
#      'author': {'email': 'davi1561@purdue.edu', 'name': 'Benjamin Davis'},
#      'message': 'Fix create-project. FS rmdir not working',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/purduesigbots/pros-vsc/commits/0a9b1421d420955df696722fd5e1f669da43a1b1'}]},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z',
#   'org': {'id': 14814081,
#    'login': 'purduesigbots',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/purduesigbots',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14814081?'}},
#  {'id': '19665372577',
#   'type': 'PushEvent',
#   'actor': {'id': 16610169,
#    'login': '365taole',
#    'display_login': '365taole',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/365taole',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/16610169?'},
#   'repo': {'id': 443490727,
#    'name': '365taole/meizi',
#    'url': 'https://api.github.com/repos/365taole/meizi'},
#   'payload': {'push_id': 8800755520,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ddf525eb85dac73ed90b0af40048340391b48f43',
#    'before': '206151f2e4848c275493d3dfa37b94ebcf459bd6',
#    'commits': [{'sha': 'ddf525eb85dac73ed90b0af40048340391b48f43',
#      'author': {'email': '365taole@gmail.com', 'name': '365taole'},
#      'message': '9_35666/02145518-33-5B4.jpg',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/365taole/meizi/commits/ddf525eb85dac73ed90b0af40048340391b48f43'}]},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z'},
#  {'id': '19665372561',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 49699333,
#    'login': 'dependabot[bot]',
#    'display_login': 'dependabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#   'repo': {'id': 388796881,
#    'name': 'OllysCoding/dcr-unmigrated-clone',
#    'url': 'https://api.github.com/repos/OllysCoding/dcr-unmigrated-clone'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/OllysCoding/dcr-unmigrated-clone/issues/65',
#     'repository_url': 'https://api.github.com/repos/OllysCoding/dcr-unmigrated-clone',
#     'labels_url': 'https://api.github.com/repos/OllysCoding/dcr-unmigrated-clone/issues/65/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/OllysCoding/dcr-unmigrated-clone/issues/65/comments',
#     'events_url': 'https://api.github.com/repos/OllysCoding/dcr-unmigrated-clone/issues/65/events',
#     'html_url': 'https://github.com/OllysCoding/dcr-unmigrated-clone/pull/65',
#     'id': 1076087258,
#     'node_id': 'PR_kwDOFyyR0c4vo_QK',
#     'number': 65,
#     'title': 'Bump @storybook/builder-webpack5 from 6.2.9 to 6.4.9',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'labels': [{'id': 3193984041,
#       'node_id': 'MDU6TGFiZWwzMTkzOTg0MDQx',
#       'url': 'https://api.github.com/repos/OllysCoding/dcr-unmigrated-clone/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 0,
#     'created_at': '2021-12-09T21:57:24Z',
#     'updated_at': '2022-01-10T21:48:38Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'draft': False,
#     'pull_request': {'url': 'https://api.github.com/repos/OllysCoding/dcr-unmigrated-clone/pulls/65',
#      'html_url': 'https://github.com/OllysCoding/dcr-unmigrated-clone/pull/65',
#      'diff_url': 'https://github.com/OllysCoding/dcr-unmigrated-clone/pull/65.diff',
#      'patch_url': 'https://github.com/OllysCoding/dcr-unmigrated-clone/pull/65.patch',
#      'merged_at': None},
#     'body': 'Bumps [@storybook/builder-webpack5](https://github.com/storybookjs/storybook/tree/HEAD/lib/core) from 6.2.9 to 6.4.9.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/storybookjs/storybook/releases"><code>@\u200bstorybook/builder-webpack5</code>\'s releases</a>.</em></p>\n<blockquote>\n<h2>v6.4.9</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>Core: Ensure we have a full story index before caching (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16947">#16947</a>)</li>\n<li>Angular: Fix support for non-roman alphabets in story titles (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16931">#16931</a>)</li>\n<li>Core: Be explicit about <code>viewMode</code> to fix Vue issue (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16919">#16919</a>)</li>\n<li>Core: Remove unused and occluded types (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16917">#16917</a>)</li>\n</ul>\n<h2>v6.4.8</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>Core: Fix auto-title in webpack5 (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16913">#16913</a>)</li>\n<li>CLI: Fix <code>sb repro</code> clobbering .vuerc (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16897">#16897</a>)</li>\n</ul>\n<h3>Maintenance</h3>\n<ul>\n<li>Core: Add feature flag to disable legacy hierarchy separator warning (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16915">#16915</a>)</li>\n</ul>\n<h2>v6.4.7</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>Angular: Fix incorrect log (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16885">#16885</a>)</li>\n</ul>\n<h2>v6.4.5</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>Angular: Fix tsConfig paths not resolving for Angular &gt;=12.2 (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16882">#16882</a>)</li>\n<li>Addon-docs: Fix transclusion crash on webpack rules without test field (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16873">#16873</a>)</li>\n</ul>\n<h3>Dependency Upgrades</h3>\n<ul>\n<li>Bump lodash to 4.17.21 (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16883">#16883</a>)</li>\n</ul>\n<h2>v6.4.4</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>CLI: Fix mainjsFramework automigrate (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16866">#16866</a>)</li>\n</ul>\n<h2>v6.4.3</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>Don\'t render with <code>modernInline</code> if <code>inlineStories</code> is <code>false</code> (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16853">#16853</a>)</li>\n<li>Preview: Don\'t hide the story while preparing (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16850">#16850</a>)</li>\n</ul>\n<h2>v6.4.2</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>UI: Ensure all classes+animations for our loaders are prefixed (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16815">#16815</a>)</li>\n<li>Angular: Add back-compat method to find options (styles) in angular.json (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16832">#16832</a>)</li>\n</ul>\n<!-- raw HTML omitted -->\n</blockquote>\n<p>... (truncated)</p>\n</details>\n<details>\n<summary>Changelog</summary>\n<p><em>Sourced from <a href="https://github.com/storybookjs/storybook/blob/next/CHANGELOG.md"><code>@\u200bstorybook/builder-webpack5</code>\'s changelog</a>.</em></p>\n<blockquote>\n<h2>6.4.9 (December 9, 2021)</h2>\n<h3>Bug Fixes</h3>\n<ul>\n<li>Core: Ensure we have a full story index before caching (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16947">#16947</a>)</li>\n<li>Angular: Fix support for non-roman alphabets in story titles (<a href="https://github-redirect.dependabot.com/storybookjs/storybook/pull/16931">#1693 ...
#     'reactions': {'url': 'https://api.github.com/repos/OllysCoding/dcr-unmigrated-clone/issues/65/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/OllysCoding/dcr-unmigrated-clone/issues/65/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/OllysCoding/dcr-unmigrated-clone/issues/comments/1009376322',
#     'html_url': 'https://github.com/OllysCoding/dcr-unmigrated-clone/pull/65#issuecomment-1009376322',
#     'issue_url': 'https://api.github.com/repos/OllysCoding/dcr-unmigrated-clone/issues/65',
#     'id': 1009376322,
#     'node_id': 'IC_kwDOFyyR0c48KdxC',
#     'user': {'login': 'dependabot[bot]',
#      'id': 49699333,
#      'node_id': 'MDM6Qm90NDk2OTkzMzM=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/29110?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot',
#      'followers_url': 'https://api.github.com/users/dependabot%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot%5Bbot%5D/starred{/owner}{/repo}',
# ...
#     'reactions': {'url': 'https://api.github.com/repos/saltstack/salt/issues/56544/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/saltstack/salt/issues/56544/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/saltstack/salt/issues/comments/1009376253',
#     'html_url': 'https://github.com/saltstack/salt/issues/56544#issuecomment-1009376253',
#     'issue_url': 'https://api.github.com/repos/saltstack/salt/issues/56544',
#     'id': 1009376253,
#     'node_id': 'IC_kwDOABU2qM48Kdv9',
#     'user': {'login': 'barbaricyawps',
#      'id': 43180546,
#      'node_id': 'MDQ6VXNlcjQzMTgwNTQ2',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/43180546?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/barbaricyawps',
#      'html_url': 'https://github.com/barbaricyawps',
#      'followers_url': 'https://api.github.com/users/barbaricyawps/followers',
#      'following_url': 'https://api.github.com/users/barbaricyawps/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/barbaricyawps/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/barbaricyawps/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/barbaricyawps/subscriptions',
#      'organizations_url': 'https://api.github.com/users/barbaricyawps/orgs',
#      'repos_url': 'https://api.github.com/users/barbaricyawps/repos',
#      'events_url': 'https://api.github.com/users/barbaricyawps/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/barbaricyawps/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2022-01-10T21:48:33Z',
#     'updated_at': '2022-01-10T21:48:33Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': "In light of @ggiesen 's comment, I am closing this issue.",
#     'reactions': {'url': 'https://api.github.com/repos/saltstack/salt/issues/comments/1009376253/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z',
#   'org': {'id': 1147473,
#    'login': 'saltstack',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/saltstack',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1147473?'}},
#  {'id': '19665372516',
#   'type': 'WatchEvent',
#   'actor': {'id': 5707335,
#    'login': 'thiagodelgado',
#    'display_login': 'thiagodelgado',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/thiagodelgado',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5707335?'},
#   'repo': {'id': 107108009,
#    'name': 'Yoctol/bottender',
#    'url': 'https://api.github.com/repos/Yoctol/bottender'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z',
#   'org': {'id': 10671553,
#    'login': 'Yoctol',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Yoctol',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10671553?'}},
#  {'id': '19665372544',
#   'type': 'CreateEvent',
#   'actor': {'id': 97480978,
#    'login': 'quventum',
#    'display_login': 'quventum',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/quventum',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97480978?'},
#   'repo': {'id': 446592251,
#    'name': 'quventum/Login-Panel-Master',
#    'url': 'https://api.github.com/repos/quventum/Login-Panel-Master'},
#   'payload': {'ref': 'main',
#    'ref_type': 'branch',
#    'master_branch': 'main',
#    'description': 'Login-Panel-Master',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z'},
#  {'id': '19665372520',
#   'type': 'PushEvent',
#   'actor': {'id': 76162501,
#    'login': 'sebciulina',
#    'display_login': 'sebciulina',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/sebciulina',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76162501?'},
#   'repo': {'id': 446590229,
#    'name': 'sebciulina/ASD2',
#    'url': 'https://api.github.com/repos/sebciulina/ASD2'},
#   'payload': {'push_id': 8800755497,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'b7d61c8585aa8279e002c2cd515e0de360b3be2e',
#    'before': '7e37e6bf4545cf01916e644d4ed9efc66cc91416',
#    'commits': [{'sha': 'b7d61c8585aa8279e002c2cd515e0de360b3be2e',
#      'author': {'email': 'sgransicki@gmail.com', 'name': 'sebciulina'},
#      'message': 'initial commit',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/sebciulina/ASD2/commits/b7d61c8585aa8279e002c2cd515e0de360b3be2e'}]},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z'},
#  {'id': '19665372517',
#   'type': 'CreateEvent',
#   'actor': {'id': 52217056,
#    'login': 'rtjohnson0',
#    'display_login': 'rtjohnson0',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rtjohnson0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52217056?'},
#   'repo': {'id': 446592255,
#    'name': 'rtjohnson0/dwdwdw',
#    'url': 'https://api.github.com/repos/rtjohnson0/dwdwdw'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'master',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z'},
#  {'id': '19665372525',
#   'type': 'CreateEvent',
#   'actor': {'id': 97479061,
#    'login': 'cdang000703',
#    'display_login': 'cdang000703',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/cdang000703',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/97479061?'},
#   'repo': {'id': 446592254,
#    'name': 'cdang000703/myrepo',
#    'url': 'https://api.github.com/repos/cdang000703/myrepo'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': 'MACS 30500 Setup Test',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z'},
#  {'id': '19665372496',
#   'type': 'PushEvent',
#   'actor': {'id': 94826692,
#    'login': 'Lexamenrf44',
#    'display_login': 'Lexamenrf44',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Lexamenrf44',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94826692?'},
#   'repo': {'id': 438363580,
#    'name': 'Lexamenrf44/lexamenrf44-demoqa-practice-form-testing',
#    'url': 'https://api.github.com/repos/Lexamenrf44/lexamenrf44-demoqa-practice-form-testing'},
#   'payload': {'push_id': 8800755477,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/page_objects_home_assignment',
#    'head': '2e391c20eac6e96b2746ff3eef6c32b295465c72',
#    'before': 'e412b99b0037bb60ee2d993e4b5c897304edd289',
#    'commits': [{'sha': '2e391c20eac6e96b2746ff3eef6c32b295465c72',
#      'author': {'email': 'alexander.stcstudent@gmail.com',
#       'name': 'Lexamenrf44'},
#      'message': 'editing "page_objects_home_assignment" branch, editing HomeAssignmentWithPageObjectsAndDsl.java,ConstantsForRegForm.java and RegistrationForm.java',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Lexamenrf44/lexamenrf44-demoqa-practice-form-testing/commits/2e391c20eac6e96b2746ff3eef6c32b295465c72'}]},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z'},
#  {'id': '19665372468',
#   'type': 'WatchEvent',
#   'actor': {'id': 44380731,
#    'login': 'alibabaoglu',
#    'display_login': 'alibabaoglu',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/alibabaoglu',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/44380731?'},
#   'repo': {'id': 113767088,
#    'name': 'dsasmblr/game-hacking',
#    'url': 'https://api.github.com/repos/dsasmblr/game-hacking'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z'},
#  {'id': '19665372497',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 22429695,
#    'login': 'codecov[bot]',
#    'display_login': 'codecov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/codecov[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22429695?'},
#   'repo': {'id': 134595546,
#    'name': 'ApollosProject/apollos-apps',
#    'url': 'https://api.github.com/repos/ApollosProject/apollos-apps'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/ApollosProject/apollos-apps/issues/2316',
#     'repository_url': 'https://api.github.com/repos/ApollosProject/apollos-apps',
#     'labels_url': 'https://api.github.com/repos/ApollosProject/apollos-apps/issues/2316/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/ApollosProject/apollos-apps/issues/2316/comments',
#     'events_url': 'https://api.github.com/repos/ApollosProject/apollos-apps/issues/2316/events',
#     'html_url': 'https://github.com/ApollosProject/apollos-apps/pull/2316',
#     'id': 1098399173,
#     'node_id': 'PR_kwDOCAXD2s4wwno8',
#     'number': 2316,
#     'title': 'feat: adds app tabs query to API',
#     'user': {'login': 'redreceipt',
#      'id': 2659478,
#      'node_id': 'MDQ6VXNlcjI2NTk0Nzg=',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/2659478?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/redreceipt',
#      'html_url': 'https://github.com/redreceipt',
#      'followers_url': 'https://api.github.com/users/redreceipt/followers',
#      'following_url': 'https://api.github.com/users/redreceipt/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/redreceipt/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/redreceipt/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/redreceipt/subscriptions',
#      'organizations_url': 'https://api.github.com/users/redreceipt/orgs',
#      'repos_url': 'https://api.github.com/users/redreceipt/repos',
#      'events_url': 'https://api.github.com/users/redreceipt/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/redreceipt/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 1,
#     'created_at': '2022-01-10T21:17:57Z',
#     'updated_at': '2022-01-10T21:48:38Z',
#     'closed_at': None,
#     'author_association': 'MEMBER',
#     'active_lock_reason': None,
#     'draft': True,
#     'pull_request': {'url': 'https://api.github.com/repos/ApollosProject/apollos-apps/pulls/2316',
#      'html_url': 'https://github.com/ApollosProject/apollos-apps/pull/2316',
#      'diff_url': 'https://github.com/ApollosProject/apollos-apps/pull/2316.diff',
#      'patch_url': 'https://github.com/ApollosProject/apollos-apps/pull/2316.patch',
#      'merged_at': None},
#     'body': None,
#     'reactions': {'url': 'https://api.github.com/repos/ApollosProject/apollos-apps/issues/2316/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'timeline_url': 'https://api.github.com/repos/ApollosProject/apollos-apps/issues/2316/timeline',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/ApollosProject/apollos-apps/issues/comments/1009376314',
#     'html_url': 'https://github.com/ApollosProject/apollos-apps/pull/2316#issuecomment-1009376314',
#     'issue_url': 'https://api.github.com/repos/ApollosProject/apollos-apps/issues/2316',
#     'id': 1009376314,
#     'node_id': 'IC_kwDOCAXD2s48Kdw6',
#     'user': {'login': 'codecov[bot]',
#      'id': 22429695,
#      'node_id': 'MDM6Qm90MjI0Mjk2OTU=',
#      'avatar_url': 'https://avatars.githubusercontent.com/in/254?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/codecov%5Bbot%5D',
#      'html_url': 'https://github.com/apps/codecov',
#      'followers_url': 'https://api.github.com/users/codecov%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/codecov%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/codecov%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/codecov%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/codecov%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/codecov%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/codecov%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/codecov%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/codecov%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'created_at': '2022-01-10T21:48:37Z',
#     'updated_at': '2022-01-10T21:48:37Z',
#     'author_association': 'NONE',
#     'body': '# [Codecov](https://codecov.io/gh/ApollosProject/apollos-apps/pull/2316?src=pr&el=h1&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=ApollosProject) Report\n> Merging [#2316](https://codecov.io/gh/ApollosProject/apollos-apps/pull/2316?src=pr&el=desc&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=ApollosProject) (627a55e) into [master](https://codecov.io/gh/ApollosProject/apollos-apps/commit/9ac75310e050cb8f79a50a71db98ca67ec527f3f?el=desc&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=ApollosProject) (9ac7531) will **decrease** coverage by `0.02%`.\n> The diff coverage is `0.00%`.\n\n[![Impacted file tree graph](https://codecov.io/gh/ApollosProject/apollos-apps/pull/2316/graphs/tree.svg?width=650&height=150&src=pr&token=apOk3YPNVm&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=ApollosProject)](https://codecov.io/gh/ApollosProject/apollos-apps/pull/2316?src=pr&el=tree&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=ApollosProject)\n\n```diff\n@@            Coverage Diff             @@\n##           master    #2316      +/-   ##\n==========================================\n- Coverage   75.07%   75.05%   -0.03%     \n==========================================\n  Files         618      618              \n  Lines        9686     9689       +3     \n  Branches     2341     2341              \n==========================================\n  Hits         7272     7272              \n- Misses       2162     2165       +3     \n  Partials      252      252              \n```\n\n| [Impacted Files](https://codecov.io/gh/ApollosProject/apollos-apps/pull/2316?src=pr&el=tree&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=ApollosProject) | Coverage Δ | |\n|---|---|---|\n| [...s-data-connector-postgres/src/features/resolver.js](https://codecov.io/gh/ApollosProject/apollos-apps/pull/2316/diff?src=pr&el=tree&utm_medium=referral&utm_source=github&utm_content=comment&utm_campaign=pr+comments&utm_term=ApollosProject#diff-cGFja2FnZXMvYXBvbGxvcy1kYXRhLWNvbm5lY3Rvci1wb3N0Z3Jlcy9zcmMvZmVhdHVyZXMvcmVzb2x2ZXIuanM=) | `8.00% <0.00%> (-1.10%)` | :arrow_down: |\n',
#     'reactions': {'url': 'https://api.github.com/repos/ApollosProject/apollos-apps/issues/comments/1009376314/reactions',
#      'total_count': 0,
#      '+1': 0,
#      '-1': 0,
#      'laugh': 0,
#      'hooray': 0,
#      'confused': 0,
#      'heart': 0,
#      'rocket': 0,
#      'eyes': 0},
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2022-01-10T21:48:38Z',
#   'org': {'id': 39307172,
#    'login': 'ApollosProject',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ApollosProject',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/39307172?'}}]

# %%
data['actor']
# Out:
# 0     {'id': 37245253, 'login': 'fazenecture', 'disp...
# 1     {'id': 3010904, 'login': 'postamar', 'display_...
# 2     {'id': 97123285, 'login': 'brokjad', 'display_...
# 3     {'id': 13698158, 'login': 'tqureshi-uog', 'dis...
# 4     {'id': 56795920, 'login': 'kitkovsky', 'displa...
# 5     {'id': 8517910, 'login': 'LombiqBot', 'display...
# 6     {'id': 65306522, 'login': 'Olga1506', 'display...
# 7     {'id': 48661356, 'login': 'BennyBot', 'display...
# 8     {'id': 16610169, 'login': '365taole', 'display...
# 9     {'id': 49699333, 'login': 'dependabot[bot]', '...
# 10    {'id': 3082812, 'login': 'IgorNovozhilov', 'di...
# 11    {'id': 51497406, 'login': 'Navid200', 'display...
# 12    {'id': 6948709, 'login': 'hmrc-web-operations'...
# 13    {'id': 92555895, 'login': 'Alrsf', 'display_lo...
# 14    {'id': 8517910, 'login': 'LombiqBot', 'display...
# 15    {'id': 73224555, 'login': 'caixina', 'display_...
# 16    {'id': 3384992, 'login': 'radazen', 'display_l...
# 17    {'id': 93337133, 'login': 'wweuwsaq', 'display...
# 18    {'id': 96735239, 'login': 'pabloenoble', 'disp...
# 19    {'id': 1012723, 'login': 'RaelZero', 'display_...
# 20    {'id': 43180546, 'login': 'barbaricyawps', 'di...
# 21    {'id': 43180546, 'login': 'barbaricyawps', 'di...
# 22    {'id': 5707335, 'login': 'thiagodelgado', 'dis...
# 23    {'id': 97480978, 'login': 'quventum', 'display...
# 24    {'id': 76162501, 'login': 'sebciulina', 'displ...
# 25    {'id': 52217056, 'login': 'rtjohnson0', 'displ...
# 26    {'id': 97479061, 'login': 'cdang000703', 'disp...
# 27    {'id': 94826692, 'login': 'Lexamenrf44', 'disp...
# 28    {'id': 44380731, 'login': 'alibabaoglu', 'disp...
# 29    {'id': 22429695, 'login': 'codecov[bot]', 'dis...
# Name: actor, dtype: object

# %%
dict(data['actor'])
# Out:
# {0: {'id': 37245253,
#   'login': 'fazenecture',
#   'display_login': 'fazenecture',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/fazenecture',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/37245253?'},
#  1: {'id': 3010904,
#   'login': 'postamar',
#   'display_login': 'postamar',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/postamar',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/3010904?'},
#  2: {'id': 97123285,
#   'login': 'brokjad',
#   'display_login': 'brokjad',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/brokjad',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/97123285?'},
#  3: {'id': 13698158,
#   'login': 'tqureshi-uog',
#   'display_login': 'tqureshi-uog',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/tqureshi-uog',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/13698158?'},
#  4: {'id': 56795920,
#   'login': 'kitkovsky',
#   'display_login': 'kitkovsky',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/kitkovsky',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/56795920?'},
#  5: {'id': 8517910,
#   'login': 'LombiqBot',
#   'display_login': 'LombiqBot',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/LombiqBot',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#  6: {'id': 65306522,
#   'login': 'Olga1506',
#   'display_login': 'Olga1506',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Olga1506',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/65306522?'},
#  7: {'id': 48661356,
#   'login': 'BennyBot',
#   'display_login': 'BennyBot',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/BennyBot',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/48661356?'},
#  8: {'id': 16610169,
#   'login': '365taole',
#   'display_login': '365taole',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/365taole',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/16610169?'},
#  9: {'id': 49699333,
#   'login': 'dependabot[bot]',
#   'display_login': 'dependabot',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/dependabot[bot]',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/49699333?'},
#  10: {'id': 3082812,
#   'login': 'IgorNovozhilov',
#   'display_login': 'IgorNovozhilov',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/IgorNovozhilov',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/3082812?'},
#  11: {'id': 51497406,
#   'login': 'Navid200',
#   'display_login': 'Navid200',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Navid200',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/51497406?'},
#  12: {'id': 6948709,
#   'login': 'hmrc-web-operations',
#   'display_login': 'hmrc-web-operations',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/hmrc-web-operations',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/6948709?'},
#  13: {'id': 92555895,
#   'login': 'Alrsf',
#   'display_login': 'Alrsf',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Alrsf',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/92555895?'},
#  14: {'id': 8517910,
#   'login': 'LombiqBot',
#   'display_login': 'LombiqBot',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/LombiqBot',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#  15: {'id': 73224555,
#   'login': 'caixina',
#   'display_login': 'caixina',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/caixina',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/73224555?'},
#  16: {'id': 3384992,
#   'login': 'radazen',
#   'display_login': 'radazen',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/radazen',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/3384992?'},
#  17: {'id': 93337133,
#   'login': 'wweuwsaq',
#   'display_login': 'wweuwsaq',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/wweuwsaq',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/93337133?'},
#  18: {'id': 96735239,
#   'login': 'pabloenoble',
#   'display_login': 'pabloenoble',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/pabloenoble',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/96735239?'},
#  19: {'id': 1012723,
#   'login': 'RaelZero',
#   'display_login': 'RaelZero',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/RaelZero',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/1012723?'},
#  20: {'id': 43180546,
#   'login': 'barbaricyawps',
#   'display_login': 'barbaricyawps',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/barbaricyawps',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/43180546?'},
#  21: {'id': 43180546,
#   'login': 'barbaricyawps',
#   'display_login': 'barbaricyawps',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/barbaricyawps',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/43180546?'},
#  22: {'id': 5707335,
#   'login': 'thiagodelgado',
#   'display_login': 'thiagodelgado',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/thiagodelgado',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/5707335?'},
#  23: {'id': 97480978,
#   'login': 'quventum',
#   'display_login': 'quventum',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/quventum',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/97480978?'},
#  24: {'id': 76162501,
#   'login': 'sebciulina',
#   'display_login': 'sebciulina',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/sebciulina',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/76162501?'},
#  25: {'id': 52217056,
#   'login': 'rtjohnson0',
#   'display_login': 'rtjohnson0',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/rtjohnson0',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/52217056?'},
#  26: {'id': 97479061,
#   'login': 'cdang000703',
#   'display_login': 'cdang000703',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/cdang000703',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/97479061?'},
#  27: {'id': 94826692,
#   'login': 'Lexamenrf44',
#   'display_login': 'Lexamenrf44',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/Lexamenrf44',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/94826692?'},
#  28: {'id': 44380731,
#   'login': 'alibabaoglu',
#   'display_login': 'alibabaoglu',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/alibabaoglu',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/44380731?'},
#  29: {'id': 22429695,
#   'login': 'codecov[bot]',
#   'display_login': 'codecov',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/codecov[bot]',
#   'avatar_url': 'https://avatars.githubusercontent.com/u/22429695?'}}

# %%
pd.DataFrame(dict(data['actor']))
# Out:
#                                                               0   \
# id                                                      37245253
# login                                                fazenecture
# display_login                                        fazenecture
# gravatar_id
# url                     https://api.github.com/users/fazenecture
# avatar_url     https://avatars.githubusercontent.com/u/37245253?
#
#                                                              1   \
# id                                                      3010904
# login                                                  postamar
# display_login                                          postamar
# gravatar_id
# url                       https://api.github.com/users/postamar
# avatar_url     https://avatars.githubusercontent.com/u/3010904?
#
#                                                               2   \
# id                                                      97123285
# login                                                    brokjad
# display_login                                            brokjad
# gravatar_id
# url                         https://api.github.com/users/brokjad
# avatar_url     https://avatars.githubusercontent.com/u/97123285?
#
#                                                               3   \
# id                                                      13698158
# login                                               tqureshi-uog
# display_login                                       tqureshi-uog
# gravatar_id
# url                    https://api.github.com/users/tqureshi-uog
# avatar_url     https://avatars.githubusercontent.com/u/13698158?
#
#                                                               4   \
# id                                                      56795920
# login                                                  kitkovsky
# display_login                                          kitkovsky
# gravatar_id
# url                       https://api.github.com/users/kitkovsky
# avatar_url     https://avatars.githubusercontent.com/u/56795920?
#
#                                                              5   \
# id                                                      8517910
# login                                                 LombiqBot
# display_login                                         LombiqBot
# gravatar_id
# url                      https://api.github.com/users/LombiqBot
# avatar_url     https://avatars.githubusercontent.com/u/8517910?
#
#                                                               6   \
# id                                                      65306522
# login                                                   Olga1506
# display_login                                           Olga1506
# gravatar_id
# url                        https://api.github.com/users/Olga1506
# avatar_url     https://avatars.githubusercontent.com/u/65306522?
#
#                                                               7   \
# id                                                      48661356
# login                                                   BennyBot
# display_login                                           BennyBot
# gravatar_id
# url                        https://api.github.com/users/BennyBot
# avatar_url     https://avatars.githubusercontent.com/u/48661356?
#
#                                                               8   \
# id                                                      16610169
# login                                                   365taole
# display_login                                           365taole
# gravatar_id
# url                        https://api.github.com/users/365taole
# avatar_url     https://avatars.githubusercontent.com/u/16610169?
#
#                                                               9   ...  \
# id                                                      49699333  ...
# login                                            dependabot[bot]  ...
# display_login                                         dependabot  ...
# gravatar_id                                                       ...
# url                 https://api.github.com/users/dependabot[bot]  ...
# avatar_url     https://avatars.githubusercontent.com/u/49699333?  ...
#
#                                                               20  \
# id                                                      43180546
# login                                              barbaricyawps
# display_login                                      barbaricyawps
# gravatar_id
# url                   https://api.github.com/users/barbaricyawps
# avatar_url     https://avatars.githubusercontent.com/u/43180546?
#
#                                                               21  \
# id                                                      43180546
# login                                              barbaricyawps
# display_login                                      barbaricyawps
# gravatar_id
# url                   https://api.github.com/users/barbaricyawps
# avatar_url     https://avatars.githubusercontent.com/u/43180546?
#
#                                                              22  \
# id                                                      5707335
# login                                             thiagodelgado
# display_login                                     thiagodelgado
# gravatar_id
# url                  https://api.github.com/users/thiagodelgado
# avatar_url     https://avatars.githubusercontent.com/u/5707335?
#
#                                                               23  \
# id                                                      97480978
# login                                                   quventum
# display_login                                           quventum
# gravatar_id
# url                        https://api.github.com/users/quventum
# avatar_url     https://avatars.githubusercontent.com/u/97480978?
#
#                                                               24  \
# id                                                      76162501
# login                                                 sebciulina
# display_login                                         sebciulina
# gravatar_id
# url                      https://api.github.com/users/sebciulina
# avatar_url     https://avatars.githubusercontent.com/u/76162501?
#
#                                                               25  \
# id                                                      52217056
# login                                                 rtjohnson0
# display_login                                         rtjohnson0
# gravatar_id
# url                      https://api.github.com/users/rtjohnson0
# avatar_url     https://avatars.githubusercontent.com/u/52217056?
#
#                                                               26  \
# id                                                      97479061
# login                                                cdang000703
# display_login                                        cdang000703
# gravatar_id
# url                     https://api.github.com/users/cdang000703
# avatar_url     https://avatars.githubusercontent.com/u/97479061?
#
#                                                               27  \
# id                                                      94826692
# login                                                Lexamenrf44
# display_login                                        Lexamenrf44
# gravatar_id
# url                     https://api.github.com/users/Lexamenrf44
# avatar_url     https://avatars.githubusercontent.com/u/94826692?
#
#                                                               28  \
# id                                                      44380731
# login                                                alibabaoglu
# display_login                                        alibabaoglu
# gravatar_id
# url                     https://api.github.com/users/alibabaoglu
# avatar_url     https://avatars.githubusercontent.com/u/44380731?
#
#                                                               29
# id                                                      22429695
# login                                               codecov[bot]
# display_login                                            codecov
# gravatar_id
# url                    https://api.github.com/users/codecov[bot]
# avatar_url     https://avatars.githubusercontent.com/u/22429695?
#
# [6 rows x 30 columns]

# %%
pd.DataFrame(dict(data['actor'])).transpose()
# Out:
#           id                login        display_login gravatar_id  \
# 0   37245253          fazenecture          fazenecture
# 1    3010904             postamar             postamar
# 2   97123285              brokjad              brokjad
# 3   13698158         tqureshi-uog         tqureshi-uog
# 4   56795920            kitkovsky            kitkovsky
# 5    8517910            LombiqBot            LombiqBot
# 6   65306522             Olga1506             Olga1506
# 7   48661356             BennyBot             BennyBot
# 8   16610169             365taole             365taole
# 9   49699333      dependabot[bot]           dependabot
# 10   3082812       IgorNovozhilov       IgorNovozhilov
# 11  51497406             Navid200             Navid200
# 12   6948709  hmrc-web-operations  hmrc-web-operations
# 13  92555895                Alrsf                Alrsf
# 14   8517910            LombiqBot            LombiqBot
# 15  73224555              caixina              caixina
# 16   3384992              radazen              radazen
# 17  93337133             wweuwsaq             wweuwsaq
# 18  96735239          pabloenoble          pabloenoble
# 19   1012723             RaelZero             RaelZero
# 20  43180546        barbaricyawps        barbaricyawps
# 21  43180546        barbaricyawps        barbaricyawps
# 22   5707335        thiagodelgado        thiagodelgado
# 23  97480978             quventum             quventum
# 24  76162501           sebciulina           sebciulina
# 25  52217056           rtjohnson0           rtjohnson0
# 26  97479061          cdang000703          cdang000703
# 27  94826692          Lexamenrf44          Lexamenrf44
# 28  44380731          alibabaoglu          alibabaoglu
# 29  22429695         codecov[bot]              codecov
#
#                                                  url  \
# 0           https://api.github.com/users/fazenecture
# 1              https://api.github.com/users/postamar
# 2               https://api.github.com/users/brokjad
# 3          https://api.github.com/users/tqureshi-uog
# 4             https://api.github.com/users/kitkovsky
# 5             https://api.github.com/users/LombiqBot
# 6              https://api.github.com/users/Olga1506
# 7              https://api.github.com/users/BennyBot
# 8              https://api.github.com/users/365taole
# 9       https://api.github.com/users/dependabot[bot]
# 10       https://api.github.com/users/IgorNovozhilov
# 11             https://api.github.com/users/Navid200
# 12  https://api.github.com/users/hmrc-web-operations
# 13                https://api.github.com/users/Alrsf
# 14            https://api.github.com/users/LombiqBot
# 15              https://api.github.com/users/caixina
# 16              https://api.github.com/users/radazen
# 17             https://api.github.com/users/wweuwsaq
# 18          https://api.github.com/users/pabloenoble
# 19             https://api.github.com/users/RaelZero
# 20        https://api.github.com/users/barbaricyawps
# 21        https://api.github.com/users/barbaricyawps
# 22        https://api.github.com/users/thiagodelgado
# 23             https://api.github.com/users/quventum
# 24           https://api.github.com/users/sebciulina
# 25           https://api.github.com/users/rtjohnson0
# 26          https://api.github.com/users/cdang000703
# 27          https://api.github.com/users/Lexamenrf44
# 28          https://api.github.com/users/alibabaoglu
# 29         https://api.github.com/users/codecov[bot]
#
#                                            avatar_url
# 0   https://avatars.githubusercontent.com/u/37245253?
# 1    https://avatars.githubusercontent.com/u/3010904?
# 2   https://avatars.githubusercontent.com/u/97123285?
# 3   https://avatars.githubusercontent.com/u/13698158?
# 4   https://avatars.githubusercontent.com/u/56795920?
# 5    https://avatars.githubusercontent.com/u/8517910?
# 6   https://avatars.githubusercontent.com/u/65306522?
# 7   https://avatars.githubusercontent.com/u/48661356?
# 8   https://avatars.githubusercontent.com/u/16610169?
# 9   https://avatars.githubusercontent.com/u/49699333?
# 10   https://avatars.githubusercontent.com/u/3082812?
# 11  https://avatars.githubusercontent.com/u/51497406?
# 12   https://avatars.githubusercontent.com/u/6948709?
# 13  https://avatars.githubusercontent.com/u/92555895?
# 14   https://avatars.githubusercontent.com/u/8517910?
# 15  https://avatars.githubusercontent.com/u/73224555?
# 16   https://avatars.githubusercontent.com/u/3384992?
# 17  https://avatars.githubusercontent.com/u/93337133?
# 18  https://avatars.githubusercontent.com/u/96735239?
# 19   https://avatars.githubusercontent.com/u/1012723?
# 20  https://avatars.githubusercontent.com/u/43180546?
# 21  https://avatars.githubusercontent.com/u/43180546?
# 22   https://avatars.githubusercontent.com/u/5707335?
# 23  https://avatars.githubusercontent.com/u/97480978?
# 24  https://avatars.githubusercontent.com/u/76162501?
# 25  https://avatars.githubusercontent.com/u/52217056?
# 26  https://avatars.githubusercontent.com/u/97479061?
# 27  https://avatars.githubusercontent.com/u/94826692?
# 28  https://avatars.githubusercontent.com/u/44380731?
# 29  https://avatars.githubusercontent.com/u/22429695?

# %%
data.columns
# Out:
# Index(['id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at',
#        'org'],
#       dtype='object')

# %%
pd.DataFrame(dict(data['org'])).transpose()
# Out:
#           id           login gravatar_id  \
# 0        NaN             NaN         NaN
# 1    6748139     cockroachdb
# 2        NaN             NaN         NaN
# 3   15328052          ccswbs
# 4        NaN             NaN         NaN
# 5    8158177          Lombiq
# 6        NaN             NaN         NaN
# 7   14814081   purduesigbots
# 8        NaN             NaN         NaN
# 9        NaN             NaN         NaN
# 10  74302247         q3s-dev
# 11       NaN             NaN         NaN
# 12   5755339            hmrc
# 13       NaN             NaN         NaN
# 14   8158177          Lombiq
# 15       NaN             NaN         NaN
# 16  83274174      gallery-so
# 17       NaN             NaN         NaN
# 18       NaN             NaN         NaN
# 19   3082775   ValveSoftware
# 20   1147473       saltstack
# 21   1147473       saltstack
# 22  10671553          Yoctol
# 23       NaN             NaN         NaN
# 24       NaN             NaN         NaN
# 25       NaN             NaN         NaN
# 26       NaN             NaN         NaN
# 27       NaN             NaN         NaN
# 28       NaN             NaN         NaN
# 29  39307172  ApollosProject
#
#                                            url  \
# 0                                          NaN
# 1      https://api.github.com/orgs/cockroachdb
# 2                                          NaN
# 3           https://api.github.com/orgs/ccswbs
# 4                                          NaN
# 5           https://api.github.com/orgs/Lombiq
# 6                                          NaN
# 7    https://api.github.com/orgs/purduesigbots
# 8                                          NaN
# 9                                          NaN
# 10         https://api.github.com/orgs/q3s-dev
# 11                                         NaN
# 12            https://api.github.com/orgs/hmrc
# 13                                         NaN
# 14          https://api.github.com/orgs/Lombiq
# 15                                         NaN
# 16      https://api.github.com/orgs/gallery-so
# 17                                         NaN
# 18                                         NaN
# 19   https://api.github.com/orgs/ValveSoftware
# 20       https://api.github.com/orgs/saltstack
# 21       https://api.github.com/orgs/saltstack
# 22          https://api.github.com/orgs/Yoctol
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29  https://api.github.com/orgs/ApollosProject
#
#                                            avatar_url
# 0                                                 NaN
# 1    https://avatars.githubusercontent.com/u/6748139?
# 2                                                 NaN
# 3   https://avatars.githubusercontent.com/u/15328052?
# 4                                                 NaN
# 5    https://avatars.githubusercontent.com/u/8158177?
# 6                                                 NaN
# 7   https://avatars.githubusercontent.com/u/14814081?
# 8                                                 NaN
# 9                                                 NaN
# 10  https://avatars.githubusercontent.com/u/74302247?
# 11                                                NaN
# 12   https://avatars.githubusercontent.com/u/5755339?
# 13                                                NaN
# 14   https://avatars.githubusercontent.com/u/8158177?
# 15                                                NaN
# 16  https://avatars.githubusercontent.com/u/83274174?
# 17                                                NaN
# 18                                                NaN
# 19   https://avatars.githubusercontent.com/u/3082775?
# 20   https://avatars.githubusercontent.com/u/1147473?
# 21   https://avatars.githubusercontent.com/u/1147473?
# 22  https://avatars.githubusercontent.com/u/10671553?
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  https://avatars.githubusercontent.com/u/39307172?

# %%
from pandas.io.json import json_normalize
response = requests.get('https://api.github.com/events')
results = response.json()
flattened_data = json_normalize(results)
flattened_data = pd.DataFrame(flattened_data)
flattened_data.head()
# Out:
# <ipython-input-24-587b3ff4fc1c>:4: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
#             id         type  public            created_at  actor.id  \
# 0  19666152894    PushEvent    True  2022-01-10T22:50:18Z  88212490
# 1  19666152897  CreateEvent    True  2022-01-10T22:50:18Z   5303311
# 2  19666152909    PushEvent    True  2022-01-10T22:50:18Z   2836374
# 3  19666152914    PushEvent    True  2022-01-10T22:50:18Z  65875762
# 4  19666152854    PushEvent    True  2022-01-10T22:50:18Z  41898282
#
#            actor.login actor.display_login actor.gravatar_id  \
# 0      tristanharrower     tristanharrower
# 1               larauj              larauj
# 2             timhoffm            timhoffm
# 3     katherine-sussol    katherine-sussol
# 4  github-actions[bot]      github-actions
#
#                                           actor.url  \
# 0      https://api.github.com/users/tristanharrower
# 1               https://api.github.com/users/larauj
# 2             https://api.github.com/users/timhoffm
# 3     https://api.github.com/users/katherine-sussol
# 4  https://api.github.com/users/github-actions[bot]
#
#                                     actor.avatar_url  ...  \
# 0  https://avatars.githubusercontent.com/u/88212490?  ...
# 1   https://avatars.githubusercontent.com/u/5303311?  ...
# 2   https://avatars.githubusercontent.com/u/2836374?  ...
# 3  https://avatars.githubusercontent.com/u/65875762?  ...
# 4  https://avatars.githubusercontent.com/u/41898282?  ...
#
#    payload.pull_request.merged_by.following_url  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   payload.pull_request.merged_by.gists_url  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   payload.pull_request.merged_by.starred_url  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    payload.pull_request.merged_by.subscriptions_url  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    payload.pull_request.merged_by.organizations_url  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    payload.pull_request.merged_by.repos_url  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   payload.pull_request.merged_by.events_url  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   payload.pull_request.merged_by.received_events_url  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   payload.pull_request.merged_by.type  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   payload.pull_request.merged_by.site_admin
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
# [5 rows x 386 columns]

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
requests.get('https://api.github.com/users/haggarw3/repos').content
# Out:
# b'[{"id":381426739,"node_id":"MDEwOlJlcG9zaXRvcnkzODE0MjY3Mzk=","name":"20778-Analyzing-Data-with-Power-BI","full_name":"haggarw3/20778-Analyzing-Data-with-Power-BI","private":false,"owner":{"login":"haggarw3","id":22273533,"node_id":"MDQ6VXNlcjIyMjczNTMz","avatar_url":"https://avatars.githubusercontent.com/u/22273533?v=4","gravatar_id":"","url":"https://api.github.com/users/haggarw3","html_url":"https://github.com/haggarw3","followers_url":"https://api.github.com/users/haggarw3/followers","following_url":"https://api.github.com/users/haggarw3/following{/other_user}","gists_url":"https://api.github.com/users/haggarw3/gists{/gist_id}","starred_url":"https://api.github.com/users/haggarw3/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/haggarw3/subscriptions","organizations_url":"https://api.github.com/users/haggarw3/orgs","repos_url":"https://api.github.com/users/haggarw3/repos","events_url":"https://api.github.com/users/haggarw3/events{/privacy}","received_events_url":"https://api.github.com/users/haggarw3/received_events","type":"User","site_admin":false},"html_url":"https://github.com/haggarw3/20778-Analyzing-Data-with-Power-BI","description":"Analyzing Data with Power BI","fork":true,"url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI","forks_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/forks","keys_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/keys{/key_id}","collaborators_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/collaborators{/collaborator}","teams_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/teams","hooks_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/hooks","issue_events_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/issues/events{/number}","events_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/events","assignees_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/assignees{/user}","branches_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/branches{/branch}","tags_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/tags","blobs_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/git/blobs{/sha}","git_tags_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/git/tags{/sha}","git_refs_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/git/refs{/sha}","trees_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/git/trees{/sha}","statuses_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/statuses/{sha}","languages_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/languages","stargazers_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/stargazers","contributors_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/contributors","subscribers_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/subscribers","subscription_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/subscription","commits_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/commits{/sha}","git_commits_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/git/commits{/sha}","comments_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/comments{/number}","issue_comment_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/issues/comments{/number}","contents_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/contents/{+path}","compare_url":"https://api.github.com/repos/haggarw3/20778-Analyzing-Data ...

# %%
import requests
import json
import getpass

username = 'haggarw3'
token = getpass.getpass(prompt='Token: ', stream=None)

# Create a re-usable session object with the user creds in-built
gh_session = requests.Session()
gh_session.auth = (username, token)
# Out:
# Token: ········

# %%
json.loads(gh_session.get('https://api.github.com/users/haggarw3/repos').text)
# Out:
# [{'id': 381426739,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzODE0MjY3Mzk=',
#   'name': '20778-Analyzing-Data-with-Power-BI',
#   'full_name': 'haggarw3/20778-Analyzing-Data-with-Power-BI',
#   'private': False,
#   'owner': {'login': 'haggarw3',
#    'id': 22273533,
#    'node_id': 'MDQ6VXNlcjIyMjczNTMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22273533?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/haggarw3',
#    'html_url': 'https://github.com/haggarw3',
#    'followers_url': 'https://api.github.com/users/haggarw3/followers',
#    'following_url': 'https://api.github.com/users/haggarw3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/haggarw3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/haggarw3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/haggarw3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/haggarw3/orgs',
#    'repos_url': 'https://api.github.com/users/haggarw3/repos',
#    'events_url': 'https://api.github.com/users/haggarw3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/haggarw3/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/haggarw3/20778-Analyzing-Data-with-Power-BI',
#   'description': 'Analyzing Data with Power BI',
#   'fork': True,
#   'url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI',
#   'forks_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/forks',
#   'keys_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/teams',
#   'hooks_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/hooks',
#   'issue_events_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/events',
#   'assignees_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/tags',
#   'blobs_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/languages',
#   'stargazers_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/stargazers',
#   'contributors_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/contributors',
#   'subscribers_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/subscribers',
#   'subscription_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/subscription',
#   'commits_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/merges',
#   'archive_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/downloads',
#   'issues_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/haggarw3/20778-Analyzing-Data-with-Power-BI/deployments',
#   'created_at': '2021-06-29T16:15:11Z',
#   'updated_at': '2021-06-29T16:15:12Z',
#   'pushed_at': '2020-02-04T14:58:24Z',
#   'git_url': 'git://github.com/haggarw3/20778-Analyzing-Data-with-Power-BI.git',
#   'ssh_url': 'git@github.com:haggarw3/20778-Analyzing-Data-with-Power-BI.git',
#   'clone_url': 'https://github.com/haggarw3/20778-Analyzing-Data-with-Power-BI.git',
#   'svn_url': 'https://github.com/haggarw3/20778-Analyzing-Data-with-Power-BI',
#   'homepage': None,
#   'size': 271384,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 255509246,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNTU1MDkyNDY=',
#   'name': 'abTestingCaseStudy',
#   'full_name': 'haggarw3/abTestingCaseStudy',
#   'private': False,
#   'owner': {'login': 'haggarw3',
#    'id': 22273533,
#    'node_id': 'MDQ6VXNlcjIyMjczNTMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22273533?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/haggarw3',
#    'html_url': 'https://github.com/haggarw3',
#    'followers_url': 'https://api.github.com/users/haggarw3/followers',
#    'following_url': 'https://api.github.com/users/haggarw3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/haggarw3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/haggarw3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/haggarw3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/haggarw3/orgs',
#    'repos_url': 'https://api.github.com/users/haggarw3/repos',
#    'events_url': 'https://api.github.com/users/haggarw3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/haggarw3/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/haggarw3/abTestingCaseStudy',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy',
#   'forks_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/forks',
#   'keys_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/teams',
#   'hooks_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/hooks',
#   'issue_events_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/events',
#   'assignees_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/tags',
#   'blobs_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/languages',
#   'stargazers_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/stargazers',
#   'contributors_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/contributors',
#   'subscribers_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/subscribers',
#   'subscription_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/subscription',
#   'commits_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/merges',
#   'archive_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/downloads',
#   'issues_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/haggarw3/abTestingCaseStudy/deployments',
#   'created_at': '2020-04-14T04:23:30Z',
#   'updated_at': '2020-04-15T20:38:40Z',
#   'pushed_at': '2020-04-15T20:38:38Z',
#   'git_url': 'git://github.com/haggarw3/abTestingCaseStudy.git',
#   'ssh_url': 'git@github.com:haggarw3/abTestingCaseStudy.git',
#   'clone_url': 'https://github.com/haggarw3/abTestingCaseStudy.git',
#   'svn_url': 'https://github.com/haggarw3/abTestingCaseStudy',
#   'homepage': None,
#   'size': 30422,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 1,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 1,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 404606377,
#   'node_id': 'MDEwOlJlcG9zaXRvcnk0MDQ2MDYzNzc=',
#   'name': 'aws-glue-flatten-nested-json',
#   'full_name': 'haggarw3/aws-glue-flatten-nested-json',
#   'private': False,
#   'owner': {'login': 'haggarw3',
#    'id': 22273533,
#    'node_id': 'MDQ6VXNlcjIyMjczNTMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22273533?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/haggarw3',
#    'html_url': 'https://github.com/haggarw3',
#    'followers_url': 'https://api.github.com/users/haggarw3/followers',
#    'following_url': 'https://api.github.com/users/haggarw3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/haggarw3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/haggarw3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/haggarw3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/haggarw3/orgs',
#    'repos_url': 'https://api.github.com/users/haggarw3/repos',
#    'events_url': 'https://api.github.com/users/haggarw3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/haggarw3/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/haggarw3/aws-glue-flatten-nested-json',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json',
#   'forks_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/forks',
#   'keys_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/teams',
#   'hooks_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/hooks',
#   'issue_events_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/events',
#   'assignees_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/tags',
#   'blobs_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/languages',
#   'stargazers_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/stargazers',
#   'contributors_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/contributors',
#   'subscribers_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/subscribers',
#   'subscription_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/subscription',
#   'commits_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/merges',
#   'archive_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/downloads',
#   'issues_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/haggarw3/aws-glue-flatten-nested-json/deployments',
#   'created_at': '2021-09-09T06:10:28Z',
#   'updated_at': '2021-09-09T06:10:29Z',
#   'pushed_at': '2021-02-19T14:49:36Z',
#   'git_url': 'git://github.com/haggarw3/aws-glue-flatten-nested-json.git',
#   'ssh_url': 'git@github.com:haggarw3/aws-glue-flatten-nested-json.git',
#   'clone_url': 'https://github.com/haggarw3/aws-glue-flatten-nested-json.git',
#   'svn_url': 'https://github.com/haggarw3/aws-glue-flatten-nested-json',
#   'homepage': None,
#   'size': 416,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': {'key': 'other',
#    'name': 'Other',
#    'spdx_id': 'NOASSERTION',
#    'url': None,
#    'node_id': 'MDc6TGljZW5zZTA='},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 328973322,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMjg5NzMzMjI=',
#   'name': 'BowieMobility',
#   'full_name': 'haggarw3/BowieMobility',
#   'private': False,
#   'owner': {'login': 'haggarw3',
#    'id': 22273533,
#    'node_id': 'MDQ6VXNlcjIyMjczNTMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22273533?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/haggarw3',
#    'html_url': 'https://github.com/haggarw3',
#    'followers_url': 'https://api.github.com/users/haggarw3/followers',
#    'following_url': 'https://api.github.com/users/haggarw3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/haggarw3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/haggarw3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/haggarw3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/haggarw3/orgs',
#    'repos_url': 'https://api.github.com/users/haggarw3/repos',
#    'events_url': 'https://api.github.com/users/haggarw3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/haggarw3/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/haggarw3/BowieMobility',
#   'description': 'Project with APIs - Ironhack',
#   'fork': True,
#   'url': 'https://api.github.com/repos/haggarw3/BowieMobility',
#   'forks_url': 'https://api.github.com/repos/haggarw3/BowieMobility/forks',
#   'keys_url': 'https://api.github.com/repos/haggarw3/BowieMobility/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/haggarw3/BowieMobility/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/haggarw3/BowieMobility/teams',
#   'hooks_url': 'https://api.github.com/repos/haggarw3/BowieMobility/hooks',
#   'issue_events_url': 'https://api.github.com/repos/haggarw3/BowieMobility/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/haggarw3/BowieMobility/events',
#   'assignees_url': 'https://api.github.com/repos/haggarw3/BowieMobility/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/haggarw3/BowieMobility/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/haggarw3/BowieMobility/tags',
#   'blobs_url': 'https://api.github.com/repos/haggarw3/BowieMobility/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/haggarw3/BowieMobility/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/haggarw3/BowieMobility/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/haggarw3/BowieMobility/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/haggarw3/BowieMobility/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/haggarw3/BowieMobility/languages',
#   'stargazers_url': 'https://api.github.com/repos/haggarw3/BowieMobility/stargazers',
#   'contributors_url': 'https://api.github.com/repos/haggarw3/BowieMobility/contributors',
#   'subscribers_url': 'https://api.github.com/repos/haggarw3/BowieMobility/subscribers',
#   'subscription_url': 'https://api.github.com/repos/haggarw3/BowieMobility/subscription',
#   'commits_url': 'https://api.github.com/repos/haggarw3/BowieMobility/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/haggarw3/BowieMobility/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/haggarw3/BowieMobility/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/haggarw3/BowieMobility/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/haggarw3/BowieMobility/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/haggarw3/BowieMobility/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/haggarw3/BowieMobility/merges',
#   'archive_url': 'https://api.github.com/repos/haggarw3/BowieMobility/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/haggarw3/BowieMobility/downloads',
#   'issues_url': 'https://api.github.com/repos/haggarw3/BowieMobility/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/haggarw3/BowieMobility/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/haggarw3/BowieMobility/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/haggarw3/BowieMobility/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/haggarw3/BowieMobility/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/haggarw3/BowieMobility/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/haggarw3/BowieMobility/deployments',
#   'created_at': '2021-01-12T12:01:49Z',
#   'updated_at': '2021-01-12T12:05:54Z',
#   'pushed_at': '2021-01-12T12:12:57Z',
#   'git_url': 'git://github.com/haggarw3/BowieMobility.git',
#   'ssh_url': 'git@github.com:haggarw3/BowieMobility.git',
#   'clone_url': 'https://github.com/haggarw3/BowieMobility.git',
#   'svn_url': 'https://github.com/haggarw3/BowieMobility',
#   'homepage': '',
#   'size': 2733,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 316876517,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMTY4NzY1MTc=',
#   'name': 'case_study',
#   'full_name': 'haggarw3/case_study',
#   'private': False,
#   'owner': {'login': 'haggarw3',
#    'id': 22273533,
#    'node_id': 'MDQ6VXNlcjIyMjczNTMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22273533?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/haggarw3',
#    'html_url': 'https://github.com/haggarw3',
#    'followers_url': 'https://api.github.com/users/haggarw3/followers',
#    'following_url': 'https://api.github.com/users/haggarw3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/haggarw3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/haggarw3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/haggarw3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/haggarw3/orgs',
#    'repos_url': 'https://api.github.com/users/haggarw3/repos',
#    'events_url': 'https://api.github.com/users/haggarw3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/haggarw3/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/haggarw3/case_study',
#   'description': 'This repo contains the docs for the case study we will use in unit 7',
#   'fork': True,
#   'url': 'https://api.github.com/repos/haggarw3/case_study',
#   'forks_url': 'https://api.github.com/repos/haggarw3/case_study/forks',
#   'keys_url': 'https://api.github.com/repos/haggarw3/case_study/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/haggarw3/case_study/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/haggarw3/case_study/teams',
#   'hooks_url': 'https://api.github.com/repos/haggarw3/case_study/hooks',
#   'issue_events_url': 'https://api.github.com/repos/haggarw3/case_study/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/haggarw3/case_study/events',
#   'assignees_url': 'https://api.github.com/repos/haggarw3/case_study/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/haggarw3/case_study/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/haggarw3/case_study/tags',
#   'blobs_url': 'https://api.github.com/repos/haggarw3/case_study/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/haggarw3/case_study/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/haggarw3/case_study/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/haggarw3/case_study/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/haggarw3/case_study/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/haggarw3/case_study/languages',
#   'stargazers_url': 'https://api.github.com/repos/haggarw3/case_study/stargazers',
#   'contributors_url': 'https://api.github.com/repos/haggarw3/case_study/contributors',
#   'subscribers_url': 'https://api.github.com/repos/haggarw3/case_study/subscribers',
#   'subscription_url': 'https://api.github.com/repos/haggarw3/case_study/subscription',
#   'commits_url': 'https://api.github.com/repos/haggarw3/case_study/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/haggarw3/case_study/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/haggarw3/case_study/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/haggarw3/case_study/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/haggarw3/case_study/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/haggarw3/case_study/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/haggarw3/case_study/merges',
#   'archive_url': 'https://api.github.com/repos/haggarw3/case_study/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/haggarw3/case_study/downloads',
#   'issues_url': 'https://api.github.com/repos/haggarw3/case_study/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/haggarw3/case_study/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/haggarw3/case_study/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/haggarw3/case_study/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/haggarw3/case_study/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/haggarw3/case_study/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/haggarw3/case_study/deployments',
#   'created_at': '2020-11-29T04:36:41Z',
#   'updated_at': '2020-11-29T04:36:42Z',
#   'pushed_at': '2020-11-29T04:28:03Z',
#   'git_url': 'git://github.com/haggarw3/case_study.git',
#   'ssh_url': 'git@github.com:haggarw3/case_study.git',
#   'clone_url': 'https://github.com/haggarw3/case_study.git',
#   'svn_url': 'https://github.com/haggarw3/case_study',
#   'homepage': None,
#   'size': 0,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'main',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 383693721,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzODM2OTM3MjE=',
#   'name': 'CodeStorm',
#   'full_name': 'haggarw3/CodeStorm',
#   'private': False,
#   'owner': {'login': 'haggarw3',
#    'id': 22273533,
#    'node_id': 'MDQ6VXNlcjIyMjczNTMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22273533?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/haggarw3',
#    'html_url': 'https://github.com/haggarw3',
#    'followers_url': 'https://api.github.com/users/haggarw3/followers',
#    'following_url': 'https://api.github.com/users/haggarw3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/haggarw3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/haggarw3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/haggarw3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/haggarw3/orgs',
#    'repos_url': 'https://api.github.com/users/haggarw3/repos',
#    'events_url': 'https://api.github.com/users/haggarw3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/haggarw3/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/haggarw3/CodeStorm',
#   'description': 'competitive programming website like geeksforgeeks and hackerrank etc. developed using django framework.',
#   'fork': True,
#   'url': 'https://api.github.com/repos/haggarw3/CodeStorm',
#   'forks_url': 'https://api.github.com/repos/haggarw3/CodeStorm/forks',
#   'keys_url': 'https://api.github.com/repos/haggarw3/CodeStorm/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/haggarw3/CodeStorm/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/haggarw3/CodeStorm/teams',
#   'hooks_url': 'https://api.github.com/repos/haggarw3/CodeStorm/hooks',
#   'issue_events_url': 'https://api.github.com/repos/haggarw3/CodeStorm/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/haggarw3/CodeStorm/events',
#   'assignees_url': 'https://api.github.com/repos/haggarw3/CodeStorm/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/haggarw3/CodeStorm/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/haggarw3/CodeStorm/tags',
#   'blobs_url': 'https://api.github.com/repos/haggarw3/CodeStorm/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/haggarw3/CodeStorm/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/haggarw3/CodeStorm/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/haggarw3/CodeStorm/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/haggarw3/CodeStorm/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/haggarw3/CodeStorm/languages',
#   'stargazers_url': 'https://api.github.com/repos/haggarw3/CodeStorm/stargazers',
#   'contributors_url': 'https://api.github.com/repos/haggarw3/CodeStorm/contributors',
#   'subscribers_url': 'https://api.github.com/repos/haggarw3/CodeStorm/subscribers',
#   'subscription_url': 'https://api.github.com/repos/haggarw3/CodeStorm/subscription',
#   'commits_url': 'https://api.github.com/repos/haggarw3/CodeStorm/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/haggarw3/CodeStorm/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/haggarw3/CodeStorm/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/haggarw3/CodeStorm/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/haggarw3/CodeStorm/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/haggarw3/CodeStorm/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/haggarw3/CodeStorm/merges',
#   'archive_url': 'https://api.github.com/repos/haggarw3/CodeStorm/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/haggarw3/CodeStorm/downloads',
#   'issues_url': 'https://api.github.com/repos/haggarw3/CodeStorm/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/haggarw3/CodeStorm/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/haggarw3/CodeStorm/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/haggarw3/CodeStorm/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/haggarw3/CodeStorm/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/haggarw3/CodeStorm/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/haggarw3/CodeStorm/deployments',
#   'created_at': '2021-07-07T06:16:24Z',
#   'updated_at': '2021-07-07T06:16:24Z',
#   'pushed_at': '2020-11-23T11:38:19Z',
#   'git_url': 'git://github.com/haggarw3/CodeStorm.git',
#   'ssh_url': 'git@github.com:haggarw3/CodeStorm.git',
#   'clone_url': 'https://github.com/haggarw3/CodeStorm.git',
#   'svn_url': 'https://github.com/haggarw3/CodeStorm',
#   'homepage': 'http://apurva10.pythonanywhere.com',
#   'size': 7917,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 235374982,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMzUzNzQ5ODI=',
#   'name': 'daft-miami-0120-labs',
#   'full_name': 'haggarw3/daft-miami-0120-labs',
#   'private': False,
#   'owner': {'login': 'haggarw3',
#    'id': 22273533,
#    'node_id': 'MDQ6VXNlcjIyMjczNTMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22273533?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/haggarw3',
#    'html_url': 'https://github.com/haggarw3',
#    'followers_url': 'https://api.github.com/users/haggarw3/followers',
#    'following_url': 'https://api.github.com/users/haggarw3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/haggarw3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/haggarw3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/haggarw3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/haggarw3/orgs',
#    'repos_url': 'https://api.github.com/users/haggarw3/repos',
#    'events_url': 'https://api.github.com/users/haggarw3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/haggarw3/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/haggarw3/daft-miami-0120-labs',
#   'description': 'Labs/Exercises for Students',
#   'fork': False,
#   'url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs',
#   'forks_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/forks',
#   'keys_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/teams',
#   'hooks_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/events',
#   'assignees_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/tags',
#   'blobs_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/languages',
#   'stargazers_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/subscription',
#   'commits_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/merges',
#   'archive_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/downloads',
#   'issues_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/haggarw3/daft-miami-0120-labs/deployments',
#   'created_at': '2020-01-21T15:28:00Z',
#   'updated_at': '2020-02-24T05:58:49Z',
#   'pushed_at': '2020-02-24T05:58:44Z',
#   'git_url': 'git://github.com/haggarw3/daft-miami-0120-labs.git',
#   'ssh_url': 'git@github.com:haggarw3/daft-miami-0120-labs.git',
#   'clone_url': 'https://github.com/haggarw3/daft-miami-0120-labs.git',
#   'svn_url': 'https://github.com/haggarw3/daft-miami-0120-labs',
#   'homepage': None,
#   'size': 60662,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 3,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 5,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 3,
#   'open_issues': 5,
#   'watchers': 0,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 216898113,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMTY4OTgxMTM=',
#   'name': 'daft-miami-1019-labs',
#   'full_name': 'haggarw3/daft-miami-1019-labs',
#   'private': False,
#   'owner': {'login': 'haggarw3',
#    'id': 22273533,
#    'node_id': 'MDQ6VXNlcjIyMjczNTMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22273533?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/haggarw3',
#    'html_url': 'https://github.com/haggarw3',
#    'followers_url': 'https://api.github.com/users/haggarw3/followers',
#    'following_url': 'https://api.github.com/users/haggarw3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/haggarw3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/haggarw3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/haggarw3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/haggarw3/orgs',
#    'repos_url': 'https://api.github.com/users/haggarw3/repos',
#    'events_url': 'https://api.github.com/users/haggarw3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/haggarw3/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/haggarw3/daft-miami-1019-labs',
#   'description': None,
#   'fork': False,
#   'url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs',
#   'forks_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/forks',
#   'keys_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/teams',
#   'hooks_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/hooks',
#   'issue_events_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/events',
#   'assignees_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/tags',
#   'blobs_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/languages',
#   'stargazers_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/stargazers',
#   'contributors_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/contributors',
#   'subscribers_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/subscribers',
#   'subscription_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/subscription',
#   'commits_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/merges',
#   'archive_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/downloads',
#   'issues_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/haggarw3/daft-miami-1019-labs/deployments',
#   'created_at': '2019-10-22T19:53:57Z',
#   'updated_at': '2019-12-02T20:21:06Z',
#   'pushed_at': '2020-02-25T04:57:08Z',
#   'git_url': 'git://github.com/haggarw3/daft-miami-1019-labs.git',
#   'ssh_url': 'git@github.com:haggarw3/daft-miami-1019-labs.git',
#   'clone_url': 'https://github.com/haggarw3/daft-miami-1019-labs.git',
#   'svn_url': 'https://github.com/haggarw3/daft-miami-1019-labs',
#   'homepage': None,
#   'size': 60674,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': 'Jupyter Notebook',
#   'has_issues': True,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 6,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 95,
#   'license': {'key': 'mit',
#    'name': 'MIT License',
#    'spdx_id': 'MIT',
#    'url': 'https://api.github.com/licenses/mit',
#    'node_id': 'MDc6TGljZW5zZTEz'},
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 6,
#   'open_issues': 95,
#   'watchers': 0,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 446618306,
#   'node_id': 'R_kgDOGp7awg',
#   'name': 'Data-Analysis-and-Machine-Learning-Projects',
#   'full_name': 'haggarw3/Data-Analysis-and-Machine-Learning-Projects',
#   'private': False,
#   'owner': {'login': 'haggarw3',
#    'id': 22273533,
#    'node_id': 'MDQ6VXNlcjIyMjczNTMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22273533?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/haggarw3',
#    'html_url': 'https://github.com/haggarw3',
#    'followers_url': 'https://api.github.com/users/haggarw3/followers',
#    'following_url': 'https://api.github.com/users/haggarw3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/haggarw3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/haggarw3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/haggarw3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/haggarw3/orgs',
#    'repos_url': 'https://api.github.com/users/haggarw3/repos',
# ...
#   'keys_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/teams',
#   'hooks_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/hooks',
#   'issue_events_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/events',
#   'assignees_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/tags',
#   'blobs_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/languages',
#   'stargazers_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/stargazers',
#   'contributors_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/contributors',
#   'subscribers_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/subscribers',
#   'subscription_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/subscription',
#   'commits_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/merges',
#   'archive_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/downloads',
#   'issues_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/haggarw3/data_6.02_activities/deployments',
#   'created_at': '2020-11-08T11:15:23Z',
#   'updated_at': '2020-11-20T07:42:58Z',
#   'pushed_at': '2020-11-20T08:55:43Z',
#   'git_url': 'git://github.com/haggarw3/data_6.02_activities.git',
#   'ssh_url': 'git@github.com:haggarw3/data_6.02_activities.git',
#   'clone_url': 'https://github.com/haggarw3/data_6.02_activities.git',
#   'svn_url': 'https://github.com/haggarw3/data_6.02_activities',
#   'homepage': None,
#   'size': 1002,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 314877531,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMTQ4Nzc1MzE=',
#   'name': 'data_6.05_activities',
#   'full_name': 'haggarw3/data_6.05_activities',
#   'private': False,
#   'owner': {'login': 'haggarw3',
#    'id': 22273533,
#    'node_id': 'MDQ6VXNlcjIyMjczNTMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22273533?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/haggarw3',
#    'html_url': 'https://github.com/haggarw3',
#    'followers_url': 'https://api.github.com/users/haggarw3/followers',
#    'following_url': 'https://api.github.com/users/haggarw3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/haggarw3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/haggarw3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/haggarw3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/haggarw3/orgs',
#    'repos_url': 'https://api.github.com/users/haggarw3/repos',
#    'events_url': 'https://api.github.com/users/haggarw3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/haggarw3/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/haggarw3/data_6.05_activities',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/haggarw3/data_6.05_activities',
#   'forks_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/forks',
#   'keys_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/teams',
#   'hooks_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/hooks',
#   'issue_events_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/events',
#   'assignees_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/tags',
#   'blobs_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/languages',
#   'stargazers_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/stargazers',
#   'contributors_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/contributors',
#   'subscribers_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/subscribers',
#   'subscription_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/subscription',
#   'commits_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/merges',
#   'archive_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/downloads',
#   'issues_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/haggarw3/data_6.05_activities/deployments',
#   'created_at': '2020-11-21T18:29:38Z',
#   'updated_at': '2020-11-21T18:29:39Z',
#   'pushed_at': '2020-11-10T00:12:12Z',
#   'git_url': 'git://github.com/haggarw3/data_6.05_activities.git',
#   'ssh_url': 'git@github.com:haggarw3/data_6.05_activities.git',
#   'clone_url': 'https://github.com/haggarw3/data_6.05_activities.git',
#   'svn_url': 'https://github.com/haggarw3/data_6.05_activities',
#   'homepage': None,
#   'size': 13788,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}},
#  {'id': 316675074,
#   'node_id': 'MDEwOlJlcG9zaXRvcnkzMTY2NzUwNzQ=',
#   'name': 'data_7.06_activities',
#   'full_name': 'haggarw3/data_7.06_activities',
#   'private': False,
#   'owner': {'login': 'haggarw3',
#    'id': 22273533,
#    'node_id': 'MDQ6VXNlcjIyMjczNTMz',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22273533?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/haggarw3',
#    'html_url': 'https://github.com/haggarw3',
#    'followers_url': 'https://api.github.com/users/haggarw3/followers',
#    'following_url': 'https://api.github.com/users/haggarw3/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/haggarw3/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/haggarw3/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/haggarw3/subscriptions',
#    'organizations_url': 'https://api.github.com/users/haggarw3/orgs',
#    'repos_url': 'https://api.github.com/users/haggarw3/repos',
#    'events_url': 'https://api.github.com/users/haggarw3/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/haggarw3/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'html_url': 'https://github.com/haggarw3/data_7.06_activities',
#   'description': None,
#   'fork': True,
#   'url': 'https://api.github.com/repos/haggarw3/data_7.06_activities',
#   'forks_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/forks',
#   'keys_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/keys{/key_id}',
#   'collaborators_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/collaborators{/collaborator}',
#   'teams_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/teams',
#   'hooks_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/hooks',
#   'issue_events_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/issues/events{/number}',
#   'events_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/events',
#   'assignees_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/assignees{/user}',
#   'branches_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/branches{/branch}',
#   'tags_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/tags',
#   'blobs_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/git/blobs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/git/tags{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/git/refs{/sha}',
#   'trees_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/git/trees{/sha}',
#   'statuses_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/statuses/{sha}',
#   'languages_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/languages',
#   'stargazers_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/stargazers',
#   'contributors_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/contributors',
#   'subscribers_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/subscribers',
#   'subscription_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/subscription',
#   'commits_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/commits{/sha}',
#   'git_commits_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/git/commits{/sha}',
#   'comments_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/comments{/number}',
#   'issue_comment_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/issues/comments{/number}',
#   'contents_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/contents/{+path}',
#   'compare_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/compare/{base}...{head}',
#   'merges_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/merges',
#   'archive_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/{archive_format}{/ref}',
#   'downloads_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/downloads',
#   'issues_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/issues{/number}',
#   'pulls_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/pulls{/number}',
#   'milestones_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/milestones{/number}',
#   'notifications_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/notifications{?since,all,participating}',
#   'labels_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/labels{/name}',
#   'releases_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/releases{/id}',
#   'deployments_url': 'https://api.github.com/repos/haggarw3/data_7.06_activities/deployments',
#   'created_at': '2020-11-28T06:50:23Z',
#   'updated_at': '2020-11-28T06:50:25Z',
#   'pushed_at': '2020-11-28T06:52:22Z',
#   'git_url': 'git://github.com/haggarw3/data_7.06_activities.git',
#   'ssh_url': 'git@github.com:haggarw3/data_7.06_activities.git',
#   'clone_url': 'https://github.com/haggarw3/data_7.06_activities.git',
#   'svn_url': 'https://github.com/haggarw3/data_7.06_activities',
#   'homepage': None,
#   'size': 1,
#   'stargazers_count': 0,
#   'watchers_count': 0,
#   'language': None,
#   'has_issues': False,
#   'has_projects': True,
#   'has_downloads': True,
#   'has_wiki': True,
#   'has_pages': False,
#   'forks_count': 0,
#   'mirror_url': None,
#   'archived': False,
#   'disabled': False,
#   'open_issues_count': 0,
#   'license': None,
#   'allow_forking': True,
#   'is_template': False,
#   'topics': [],
#   'visibility': 'public',
#   'forks': 0,
#   'open_issues': 0,
#   'watchers': 0,
#   'default_branch': 'master',
#   'permissions': {'admin': True,
#    'maintain': True,
#    'push': True,
#    'triage': True,
#    'pull': True}}]

# %%
json.loads(gh_session.get('https://api.github.com/user').text)
# Out:
# {'login': 'haggarw3',
#  'id': 22273533,
#  'node_id': 'MDQ6VXNlcjIyMjczNTMz',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/22273533?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/haggarw3',
#  'html_url': 'https://github.com/haggarw3',
#  'followers_url': 'https://api.github.com/users/haggarw3/followers',
#  'following_url': 'https://api.github.com/users/haggarw3/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/haggarw3/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/haggarw3/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/haggarw3/subscriptions',
#  'organizations_url': 'https://api.github.com/users/haggarw3/orgs',
#  'repos_url': 'https://api.github.com/users/haggarw3/repos',
#  'events_url': 'https://api.github.com/users/haggarw3/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/haggarw3/received_events',
#  'type': 'User',
#  'site_admin': False,
#  'name': 'Himanshu Aggarwal',
#  'company': None,
#  'blog': 'https://www.linkedin.com/in/himanshu-aggarwal-71172320/',
#  'location': 'Miami',
#  'email': 'haggarw3@asu.edu',
#  'hireable': None,
#  'bio': None,
#  'twitter_username': None,
#  'public_repos': 83,
#  'public_gists': 6,
#  'followers': 19,
#  'following': 3,
#  'created_at': '2016-09-18T10:18:41Z',
#  'updated_at': '2022-01-05T16:27:29Z',
#  'private_gists': 2,
#  'total_private_repos': 8,
#  'owned_private_repos': 7,
#  'disk_usage': 2243893,
#  'collaborators': 14,
#  'two_factor_authentication': False,
#  'plan': {'name': 'free',
#   'space': 976562499,
#   'collaborators': 0,
#   'private_repos': 10000}}
